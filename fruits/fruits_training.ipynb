# %% [markdown]
# # Training YOLO11n-cls on Fruits-360 Dataset
#
# This notebook demonstrates how to train a YOLO11n-cls model for fruit classification using the Fruits-360 dataset.

# %% [markdown]
# ## 1. Setup Environment
# First, let's install the necessary packages and import required libraries.

# %%
# Basic data handling and utilities
import os
import numpy as np
import pandas as pd
from pathlib import Path
import random
import shutil
from tqdm.notebook import tqdm

# Image processing
import cv2
from PIL import Image

# Data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# PyTorch and related libraries
import torch
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms

# Ultralytics for YOLOv11n-cls
from ultralytics import YOLO

# For reproducibility
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(42)

# Check for GPU availability
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda:0

# %%
# Define path to the prepared dataset
dataset_dir = os.path.join("..", "datasets", "fruits_yolo")

# Check if the dataset exists
if not os.path.exists(dataset_dir):
    raise FileNotFoundError(f"Dataset directory {dataset_dir} not found. Please run dataset_preparation.ipynb first.")

# Load dataset information from data.yaml
import yaml
yaml_path = os.path.join(dataset_dir, "data.yaml")

with open(yaml_path, "r") as f:
    data_config = yaml.safe_load(f)

print("Dataset configuration:")
for key, value in data_config.items():
    if key == 'names':
        print(f"  {key}: [list of {len(value)} class names]")
    else:
        print(f"  {key}: {value}")

# Define paths to the training and validation sets
train_dir = os.path.join(dataset_dir, "train")
val_dir = os.path.join(dataset_dir, "val")

# Check if we have the expected directory structure
if not os.path.exists(train_dir) or not os.path.exists(val_dir):
    raise FileNotFoundError(f"Expected directory structure not found. Please run dataset_preparation.ipynb first.")

# Class names from YAML
class_names = data_config['names']

# Count images in each class directory
class_counts = {'train': {}, 'val': {}}
total_train = 0
total_val = 0

for cls in class_names:
    train_class_dir = os.path.join(train_dir, cls)
    val_class_dir = os.path.join(val_dir, cls)
    
    if os.path.exists(train_class_dir):
        n_train = len([f for f in os.listdir(train_class_dir) if f.endswith(('.jpg', '.png', '.jpeg'))])
        class_counts['train'][cls] = n_train
        total_train += n_train
    else:
        class_counts['train'][cls] = 0
        
    if os.path.exists(val_class_dir):
        n_val = len([f for f in os.listdir(val_class_dir) if f.endswith(('.jpg', '.png', '.jpeg'))])
        class_counts['val'][cls] = n_val
        total_val += n_val
    else:
        class_counts['val'][cls] = 0

print("\nDataset statistics:")
print(f"  Training images: {total_train}")
print(f"  Validation images: {total_val}")

# Create DataFrame for visualization
df_data = []
for cls in class_names:
    df_data.append({
        'Class': cls,
        'Training': class_counts['train'].get(cls, 0),
        'Validation': class_counts['val'].get(cls, 0),
        'Total': class_counts['train'].get(cls, 0) + class_counts['val'].get(cls, 0)
    })

df = pd.DataFrame(df_data)

# Display class distribution
plt.figure(figsize=(15, 6))
plt.bar(df['Class'], df['Training'], label='Training')
plt.bar(df['Class'], df['Validation'], bottom=df['Training'], label='Validation')
plt.xticks(rotation=90)
plt.xlabel('Class')
plt.ylabel('Number of Images')
plt.title('Class Distribution')
plt.legend()
plt.tight_layout()
plt.show()

# Display top 10 classes by total count
top_classes = df.sort_values('Total', ascending=False).head(10)
print("\nTop 10 classes by number of images:")
display(top_classes)

# Display a few random examples from different classes
n_classes_to_show = min(5, len(class_names))
sample_classes = random.sample(class_names, n_classes_to_show)

plt.figure(figsize=(15, n_classes_to_show * 3))
for i, cls in enumerate(sample_classes):
    cls_dir = os.path.join(train_dir, cls)
    if not os.path.exists(cls_dir):
        continue
        
    images = [f for f in os.listdir(cls_dir) if f.endswith(('.jpg', '.png', '.jpeg'))]
    if not images:
        continue
        
    samples = random.sample(images, min(5, len(images)))
    
    for j, img_file in enumerate(samples):
        img_path = os.path.join(cls_dir, img_file)
        img = Image.open(img_path)
        
        plt.subplot(n_classes_to_show, 5, i*5 + j + 1)
        plt.imshow(img)
        plt.title(f"Class: {cls}")
        plt.axis('off')

plt.tight_layout()
plt.show()

# Confirm the dataset is ready for YOLO training
print("\nDataset is ready for YOLO training!")
print(f"YAML config path: {yaml_path}")
print("Use this path when initializing the YOLO model for training.")
# Out:
# Dataset configuration:
#   path: ../datasets/fruits_yolo
#   train: train
#   val: val
#   nc: 76
#   names: [list of 76 class names]
#
# Dataset statistics:
#   Training images: 110856
#   Validation images: 27843
# Top 10 classes by number of images:
#        Class  Training  Validation  Total
# 0      apple     17142        4302  21444
# 72    tomato     10928        2744  13672
# 16    cherry      9777        2453  12230
# 53      pear      5604        1409   7013
# 21  cucumber      4350        1091   5441
# 28     grape      3648         917   4565
# 64    quince      2875         721   3596
# 55    pepper      2641         663   3304
# 47       nut      2544         640   3184
# 2    avocado      2473         620   3093
# Dataset is ready for YOLO training!
# YAML config path: ../datasets/fruits_yolo/data.yaml
# Use this path when initializing the YOLO model for training.

# %%
# Set training parameters
# For RTX 4050 (6GB VRAM), we'll use a moderate batch size to avoid OOM errors
BATCH_SIZE = 16      # Start with a conservative batch size
EPOCHS = 25          # Number of training epochs
IMG_SIZE = 224       # Image resolution for training
MODEL_NAME = "yolo11n-cls.pt"  # Pre-trained YOLOv11n classification model

# Configure training settings for YOLO classification
train_args = {
    # "data": yaml_path,             # Path to data.yaml file
    "data": dataset_dir,             # Path to data.yaml file
    "epochs": EPOCHS,              # Number of epochs
    "imgsz": IMG_SIZE,             # Image size
    "batch": BATCH_SIZE,           # Batch size
    "device": 0,                   # Use GPU (0)
    "workers": 4,                  # Number of worker threads for data loading
    "optimizer": "AdamW",          # Optimizer
    "lr0": 0.001,                  # Initial learning rate
    "patience": 5,                 # Early stopping patience
    "project": "../runs",          # Project directory
    "name": "fruits_classification",# Experiment name
    "exist_ok": True,              # Overwrite existing experiment
    "pretrained": True,            # Use pretrained weights
    "dropout": 0.1,                # Dropout rate
    "seed": 42,                    # Random seed for reproducibility
    "cache": True,                 # Cache images for faster training
}

print(f"Starting training with batch size {BATCH_SIZE} and image size {IMG_SIZE}...")

# Load the model
model = YOLO(MODEL_NAME)

# Train the model
results = model.train(**train_args)

# Display training summary
print("\nTraining completed!")
print(f"Results saved to {os.path.join('../runs', 'fruits_classification')}")
# Out:
# Starting training with batch size 16 and image size 224...
# New https://pypi.org/project/ultralytics/8.3.159 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.158 🚀 Python-3.13.3 torch-2.7.1+cu126 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 5771MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=True, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=../datasets/fruits_yolo, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.1, dynamic=False, embed=None, epochs=25, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=fruits_classification, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=5, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=../runs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=../runs/fruits_classification, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=42, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# New https://pypi.org/project/ultralytics/8.3.159 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.158 🚀 Python-3.13.3 torch-2.7.1+cu126 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 5771MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=True, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=../datasets/fruits_yolo, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.1, dynamic=False, embed=None, epochs=25, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=fruits_classification, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=5, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=../runs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=../runs/fruits_classification, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=42, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# train: /home/kuba/Coding/Uczelnia/fridge_project/datasets/fruits_yolo/train... found 110856 images in 76 classes ✅
# train: /home/kuba/Coding/Uczelnia/fridge_project/datasets/fruits_yolo/train... found 110856 images in 76 classes ✅
# val: /home/kuba/Coding/Uczelnia/fridge_project/datasets/fruits_yolo/val... found 27843 images in 76 classes ✅
# test: None...
# val: /home/kuba/Coding/Uczelnia/fridge_project/datasets/fruits_yolo/val... found 27843 images in 76 classes ✅
# test: None...
# Overriding model.yaml nc=80 with nc=76
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
# Overriding model.yaml nc=80 with nc=76
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  10                  -1  1    427596  ultralytics.nn.modules.head.Classify         [256, 76]
#  10                  -1  1    427596  ultralytics.nn.modules.head.Classify         [256, 76]
# YOLO11n-cls summary: 86 layers, 1,628,460 parameters, 1,628,460 gradients, 3.3 GFLOPs
# Transferred 234/236 items from pretrained weights
# YOLO11n-cls summary: 86 layers, 1,628,460 parameters, 1,628,460 gradients, 3.3 GFLOPs
# Transferred 234/236 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# AMP: checks passed ✅
# WARNING ⚠️ Classification `cache_ram` training has known memory leak in https://github.com/ultralytics/ultralytics/issues/9824, setting `cache_ram=False`.
# train: Fast image access ✅ (ping: 0.0±0.1 ms, read: 39.4±20.5 MB/s, size: 7.4 KB)
# WARNING ⚠️ Classification `cache_ram` training has known memory leak in https://github.com/ultralytics/ultralytics/issues/9824, setting `cache_ram=False`.
# train: Fast image access ✅ (ping: 0.0±0.1 ms, read: 39.4±20.5 MB/s, size: 7.4 KB)
# train: Scanning /home/kuba/Coding/Uczelnia/fridge_project/datasets/fruits_yolo/train... 110856 images, 0 corrupt: 100%|██████████| 110856/110856 [00:11<00:00, 9831.60it/s]
# train: New cache created: /home/kuba/Coding/Uczelnia/fridge_project/datasets/fruits_yolo/train.cache
# WARNING ⚠️ Classification `cache_ram` training has known memory leak in https://github.com/ultralytics/ultralytics/issues/9824, setting `cache_ram=False`.
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 53.4±20.9 MB/s, size: 7.3 KB)
# WARNING ⚠️ Classification `cache_ram` training has known memory leak in https://github.com/ultralytics/ultralytics/issues/9824, setting `cache_ram=False`.
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 53.4±20.9 MB/s, size: 7.3 KB)
# val: Scanning /home/kuba/Coding/Uczelnia/fridge_project/datasets/fruits_yolo/val... 27843 images, 0 corrupt: 100%|██████████| 27843/27843 [00:02<00:00, 9760.05it/s]
# val: New cache created: /home/kuba/Coding/Uczelnia/fridge_project/datasets/fruits_yolo/val.cache
# optimizer: AdamW(lr=0.001, momentum=0.937) with parameter groups 39 weight(decay=0.0), 40 weight(decay=0.0005), 40 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 4 dataloader workers
# Logging results to ../runs/fruits_classification
# Starting training for 25 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
# optimizer: AdamW(lr=0.001, momentum=0.937) with parameter groups 39 weight(decay=0.0), 40 weight(decay=0.0005), 40 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 4 dataloader workers
# Logging results to ../runs/fruits_classification
# Starting training for 25 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#        1/25     0.256G     0.8819          8        224: 100%|██████████| 6929/6929 [02:54<00:00, 39.63it/s]
#        1/25     0.256G     0.8819          8        224: 100%|██████████| 6929/6929 [02:54<00:00, 39.63it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 871/871 [00:13<00:00, 66.16it/s]
#                    all      0.988          1
#       Epoch    GPU_mem       loss  Instances       Size
#        2/25     0.266G     0.2902          8        224: 100%|██████████| 6929/6929 [02:39<00:00, 43.50it/s]
#        2/25     0.266G     0.2902          8        224: 100%|██████████| 6929/6929 [02:39<00:00, 43.50it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 871/871 [00:12<00:00, 68.96it/s]
#                    all      0.999          1
#       Epoch    GPU_mem       loss  Instances       Size
#        3/25     0.275G     0.1927          8        224: 100%|██████████| 6929/6929 [02:35<00:00, 44.55it/s]
#        3/25     0.275G     0.1927          8        224: 100%|██████████| 6929/6929 [02:35<00:00, 44.55it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 871/871 [00:12<00:00, 68.86it/s]
#                    all          1          1
#       Epoch    GPU_mem       loss  Instances       Size
#        4/25     0.283G     0.1387          8        224: 100%|██████████| 6929/6929 [02:33<00:00, 45.27it/s]
#        4/25     0.283G     0.1387          8        224: 100%|██████████| 6929/6929 [02:33<00:00, 45.27it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 871/871 [00:12<00:00, 67.01it/s]
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#
#       Epoch    GPU_mem       loss  Instances       Size
#        5/25     0.293G    0.09965          8        224: 100%|██████████| 6929/6929 [02:32<00:00, 45.57it/s]
#        5/25     0.293G    0.09965          8        224: 100%|██████████| 6929/6929 [02:32<00:00, 45.57it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 871/871 [00:11<00:00, 74.66it/s]
#                    all          1          1
#       Epoch    GPU_mem       loss  Instances       Size
#        6/25     0.303G     0.0778          8        224: 100%|██████████| 6929/6929 [02:27<00:00, 47.10it/s]
#        6/25     0.303G     0.0778          8        224: 100%|██████████| 6929/6929 [02:27<00:00, 47.10it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 871/871 [00:11<00:00, 72.85it/s]
#                    all          1          1
#       Epoch    GPU_mem       loss  Instances       Size
#        7/25     0.312G    0.06509          8        224: 100%|██████████| 6929/6929 [02:25<00:00, 47.58it/s]
#        7/25     0.312G    0.06509          8        224: 100%|██████████| 6929/6929 [02:25<00:00, 47.58it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 871/871 [00:11<00:00, 74.40it/s]
#                    all          1          1
#       Epoch    GPU_mem       loss  Instances       Size
#        8/25      0.32G    0.05388          8        224: 100%|██████████| 6929/6929 [02:25<00:00, 47.46it/s]
#        8/25      0.32G    0.05388          8        224: 100%|██████████| 6929/6929 [02:25<00:00, 47.46it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 871/871 [00:11<00:00, 74.16it/s]
#                    all          1          1
# EarlyStopping: Training stopped early as no improvement observed in last 5 epochs. Best results observed at epoch 3, best model saved as best.pt.
# To update EarlyStopping(patience=5) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
# EarlyStopping: Training stopped early as no improvement observed in last 5 epochs. Best results observed at epoch 3, best model saved as best.pt.
# To update EarlyStopping(patience=5) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
# 8 epochs completed in 0.370 hours.
# Optimizer stripped from ../runs/fruits_classification/weights/last.pt, 3.4MB
# Optimizer stripped from ../runs/fruits_classification/weights/last.pt, 3.4MB
# Optimizer stripped from ../runs/fruits_classification/weights/best.pt, 3.4MB
#
# Validating ../runs/fruits_classification/weights/best.pt...
# Ultralytics 8.3.158 🚀 Python-3.13.3 torch-2.7.1+cu126 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 5771MiB)
# Optimizer stripped from ../runs/fruits_classification/weights/best.pt, 3.4MB
#
# Validating ../runs/fruits_classification/weights/best.pt...
# Ultralytics 8.3.158 🚀 Python-3.13.3 torch-2.7.1+cu126 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 5771MiB)
# YOLO11n-cls summary (fused): 47 layers, 1,623,380 parameters, 0 gradients, 3.2 GFLOPs
# YOLO11n-cls summary (fused): 47 layers, 1,623,380 parameters, 0 gradients, 3.2 GFLOPs
# train: /home/kuba/Coding/Uczelnia/fridge_project/datasets/fruits_yolo/train... found 110856 images in 76 classes ✅
# train: /home/kuba/Coding/Uczelnia/fridge_project/datasets/fruits_yolo/train... found 110856 images in 76 classes ✅
# val: /home/kuba/Coding/Uczelnia/fridge_project/datasets/fruits_yolo/val... found 27843 images in 76 classes ✅
# val: /home/kuba/Coding/Uczelnia/fridge_project/datasets/fruits_yolo/val... found 27843 images in 76 classes ✅
# test: None...
# test: None...
#                classes   top1_acc   top5_acc: 100%|██████████| 871/871 [00:11<00:00, 73.30it/s]
#                    all          1          1
# Speed: 0.1ms preprocess, 0.1ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to ../runs/fruits_classification
# Speed: 0.1ms preprocess, 0.1ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to ../runs/fruits_classification
#
# Training completed!
# Results saved to ../runs/fruits_classification
#
# Training completed!
# Results saved to ../runs/fruits_classification

# %% [markdown]
# ## 3. Evaluate Model Performance
#
# Now let's evaluate the trained model's performance and visualize the results.

# %%
# Load the best trained model
best_model_path = os.path.join('../runs', 'fruits_classification', 'weights', 'best.pt')
trained_model = YOLO(best_model_path)

# Fix the data.yaml file before validation
# This will convert the comma-separated string into a proper list format
with open(yaml_path, 'r') as f:
    yaml_data = yaml.safe_load(f)

# Convert the comma-separated string to a proper list
if isinstance(yaml_data['names'], str):
    yaml_data['names'] = [name.strip() for name in yaml_data['names'].split(',')]
    
    # Verify that the length matches nc
    if len(yaml_data['names']) != yaml_data['nc']:
        print(f"Warning: Found {len(yaml_data['names'])} names but nc={yaml_data['nc']}. Updating nc to match.")
        yaml_data['nc'] = len(yaml_data['names'])
    
    # Save the fixed yaml file
    fixed_yaml_path = os.path.join(dataset_dir, "data_fixed.yaml")
    with open(fixed_yaml_path, 'w') as f:
        yaml.dump(yaml_data, f, default_flow_style=False)
    
    print(f"Fixed YAML file saved to {fixed_yaml_path}")
    yaml_path = fixed_yaml_path

# Validate the model on the validation set
val_results = trained_model.val(data=yaml_path)

# Print validation metrics
print(f"Validation results:")
print(f"  Accuracy: {val_results.top1 * 100:.2f}%")  # Top-1 accuracy
print(f"  Top-5 Accuracy: {val_results.top5 * 100:.2f}%")  # Top-5 accuracy

# Make sure to use the same class_names list for the rest of the code
class_names = yaml_data['names']

# Load the training metrics from the results file
import pandas as pd
import matplotlib.pyplot as plt

try:
    metrics_csv = list(Path(os.path.join('../runs', 'fruits_classification')).glob('*.csv'))[0]
    metrics = pd.read_csv(metrics_csv)
    
    # Plot training metrics
    plt.figure(figsize=(12, 8))
    
    # Plot training and validation loss
    plt.subplot(2, 1, 1)
    plt.plot(metrics['                  epoch'], metrics['               train/loss'], label='Training Loss')
    plt.plot(metrics['                  epoch'], metrics['                 val/loss'], label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.grid(True)
    
    # Plot top-1 and top-5 accuracy
    plt.subplot(2, 1, 2)
    plt.plot(metrics['                  epoch'], metrics['                 metrics/accuracy_top1'], label='Top-1 Accuracy')
    plt.plot(metrics['                  epoch'], metrics['                 metrics/accuracy_top5'], label='Top-5 Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title('Validation Accuracy')
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    plt.show()
except Exception as e:
    print(f"Could not load training metrics: {e}")
# Out:
# Ultralytics 8.3.158 🚀 Python-3.13.3 torch-2.7.1+cu126 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 5771MiB)
# YOLO11n-cls summary (fused): 47 layers, 1,623,380 parameters, 0 gradients, 3.2 GFLOPs
# YOLO11n-cls summary (fused): 47 layers, 1,623,380 parameters, 0 gradients, 3.2 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 578.8±208.1 MB/s, size: 7.3 KB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 578.8±208.1 MB/s, size: 7.3 KB)
# val: Scanning /home/kuba/Coding/Uczelnia/fridge_project/datasets/fruits_yolo/val... 27843 images, 0 corrupt: 100%|██████████| 27843/27843 [00:00<?, ?it/s]
#
#                classes   top1_acc   top5_acc: 100%|██████████| 1741/1741 [00:11<00:00, 152.86it/s]
#                    all          1          1
# Speed: 0.1ms preprocess, 0.3ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /home/kuba/Coding/Uczelnia/fridge_project/runs/classify/val
# Speed: 0.1ms preprocess, 0.3ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /home/kuba/Coding/Uczelnia/fridge_project/runs/classify/val
# Validation results:
#   Accuracy: 100.00%
#   Top-5 Accuracy: 100.00%
# Could not load training metrics: '                  epoch'
# Validation results:
#   Accuracy: 100.00%
#   Top-5 Accuracy: 100.00%
# Could not load training metrics: '                  epoch'

# %% [markdown]
# ## 4. Test the Model on Sample Images
#
# Let's test our trained model on some sample images from the validation set.

# %%
# Test the model on some random images from the validation set
# In our new structure, we need to find images from class directories

# Get a list of sample images from each class
test_samples = []
for cls_idx, cls_name in enumerate(class_names):
    val_class_dir = os.path.join(val_dir, cls_name)
    if not os.path.exists(val_class_dir):
        continue
        
    class_images = [f for f in os.listdir(val_class_dir) if f.endswith(('.jpg', '.png', '.jpeg'))]
    if class_images:
        # Take up to 2 images from each class to get a diverse sample
        for img_file in random.sample(class_images, min(2, len(class_images))):
            test_samples.append((cls_idx, cls_name, os.path.join(val_class_dir, img_file)))

# If we have too many samples, take a subset
if len(test_samples) > 10:
    test_samples = random.sample(test_samples, 10)

plt.figure(figsize=(20, 12))
for i, (true_class_idx, true_class, img_path) in enumerate(test_samples):
    if i >= 10:  # Limit to 10 images
        break
        
    # Make prediction
    results = trained_model(img_path)
    
    # Get top prediction
    probs = results[0].probs.data.tolist()
    pred_class_idx = probs.index(max(probs))
    pred_class = class_names[pred_class_idx]
    confidence = probs[pred_class_idx]
    
    # Get top 3 predictions for display
    top3_indices = sorted(range(len(probs)), key=lambda i: probs[i], reverse=True)[:3]
    top3_classes = [(class_names[idx], probs[idx]) for idx in top3_indices]
    
    # Display image with prediction
    plt.subplot(2, 5, i+1)
    img = Image.open(img_path)
    plt.imshow(img)
    
    # Color title based on prediction correctness
    title_color = 'green' if pred_class == true_class else 'red'
    plt.title(f"True: {true_class}\nPred: {pred_class} ({confidence:.2f})", 
              color=title_color, fontweight='bold')
    
    # Display top 3 predictions as text
    y_pos = 0.95
    for cls, prob in top3_classes:
        text_color = 'green' if cls == true_class else 'black'
        plt.text(0.05, y_pos, f"{cls}: {prob:.2f}", 
                 transform=plt.gca().transAxes, color=text_color, fontsize=9)
        y_pos -= 0.06
    
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/caju/Caju seed 1_r0_172_100.jpg: 224x224 caju 1.00, pear 0.00, peach 0.00, potato 0.00, cactus fruit 0.00, 4.0ms
# Speed: 1.2ms preprocess, 4.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# Speed: 1.2ms preprocess, 4.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/pomelo/Pomelo Sweetie 1_r2_69_100.jpg: 224x224 pomelo 1.00, mango 0.00, apple 0.00, grapefruit 0.00, pear 0.00, 3.4ms
# Speed: 1.8ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/pomelo/Pomelo Sweetie 1_r2_69_100.jpg: 224x224 pomelo 1.00, mango 0.00, apple 0.00, grapefruit 0.00, pear 0.00, 3.4ms
# Speed: 1.8ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/cabbage/Cabbage white 1_r0_177_100.jpg: 224x224 cabbage 1.00, kohlrabi 0.00, corn 0.00, apple 0.00, onion 0.00, 3.0ms
# Speed: 1.2ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/cabbage/Cabbage white 1_r0_177_100.jpg: 224x224 cabbage 1.00, kohlrabi 0.00, corn 0.00, apple 0.00, onion 0.00, 3.0ms
# Speed: 1.2ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/salak/Salak 1_52_100.jpg: 224x224 salak 1.00, strawberry 0.00, lychee 0.00, nut 0.00, pear 0.00, 3.0ms
# Speed: 1.2ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/salak/Salak 1_52_100.jpg: 224x224 salak 1.00, strawberry 0.00, lychee 0.00, nut 0.00, pear 0.00, 3.0ms
# Speed: 1.2ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/cherry/Cherry Wax Red 2_r0_244_100.jpg: 224x224 cherry 1.00, tomato 0.00, apple 0.00, redcurrant 0.00, physalis 0.00, 3.2ms
# Speed: 1.1ms preprocess, 3.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/cherry/Cherry Wax Red 2_r0_244_100.jpg: 224x224 cherry 1.00, tomato 0.00, apple 0.00, redcurrant 0.00, physalis 0.00, 3.2ms
# Speed: 1.1ms preprocess, 3.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/plum/Plum 3_r2_79_100.jpg: 224x224 plum 1.00, pear 0.00, beetroot 0.00, apple 0.00, chestnut 0.00, 3.2ms
# Speed: 1.5ms preprocess, 3.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/plum/Plum 3_r2_79_100.jpg: 224x224 plum 1.00, pear 0.00, beetroot 0.00, apple 0.00, chestnut 0.00, 3.2ms
# Speed: 1.5ms preprocess, 3.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/tamarillo/Tamarillo 1_95_100.jpg: 224x224 tamarillo 1.00, apple 0.00, tomato 0.00, eggplant 0.00, banana 0.00, 3.3ms
# Speed: 1.2ms preprocess, 3.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/tamarillo/Tamarillo 1_95_100.jpg: 224x224 tamarillo 1.00, apple 0.00, tomato 0.00, eggplant 0.00, banana 0.00, 3.3ms
# Speed: 1.2ms preprocess, 3.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/cucumber/Cucumber 10_r0_171_100.jpg: 224x224 cucumber 1.00, avocado 0.00, nut 0.00, quince 0.00, eggplant 0.00, 2.8ms
# Speed: 1.0ms preprocess, 2.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/cucumber/Cucumber 10_r0_171_100.jpg: 224x224 cucumber 1.00, avocado 0.00, nut 0.00, quince 0.00, eggplant 0.00, 2.8ms
# Speed: 1.0ms preprocess, 2.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/kaki/Kaki 1_r_122_100.jpg: 224x224 kaki 1.00, clementine 0.00, tomato 0.00, tamarillo 0.00, pomegranate 0.00, 2.6ms
# Speed: 1.4ms preprocess, 2.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/kaki/Kaki 1_r_122_100.jpg: 224x224 kaki 1.00, clementine 0.00, tomato 0.00, tamarillo 0.00, pomegranate 0.00, 2.6ms
# Speed: 1.4ms preprocess, 2.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/redcurrant/Redcurrant 1_198_100.jpg: 224x224 redcurrant 1.00, tomato 0.00, pitahaya 0.00, huckleberry 0.00, apple 0.00, 2.7ms
# Speed: 1.4ms preprocess, 2.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/redcurrant/Redcurrant 1_198_100.jpg: 224x224 redcurrant 1.00, tomato 0.00, pitahaya 0.00, huckleberry 0.00, apple 0.00, 2.7ms
# Speed: 1.4ms preprocess, 2.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)

# %% [markdown]
# ## 5. Confusion Matrix
#
# Let's generate a confusion matrix to better understand the model's performance across different classes.

# %%
# Generate confusion matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

def predict_batch(model, image_data, class_names):
    """
    Run predictions on a batch of images and return true and predicted labels
    
    Args:
        model: YOLO model
        image_data: List of tuples (class_idx, class_name, image_path)
        class_names: List of all class names
    
    Returns:
        true_labels, pred_labels
    """
    true_labels = []
    pred_labels = []
    
    for class_idx, _, img_path in tqdm(image_data, desc="Predicting"):
        # True label is already known from the directory structure
        true_labels.append(class_idx)
        
        # Get prediction
        results = model(img_path)
        probs = results[0].probs.data.tolist()
        pred_idx = probs.index(max(probs))
        
        pred_labels.append(pred_idx)
    
    return true_labels, pred_labels

# Collect test samples from validation set
test_data = []
for cls_idx, cls_name in enumerate(class_names):
    val_class_dir = os.path.join(val_dir, cls_name)
    if not os.path.exists(val_class_dir):
        continue
        
    class_images = [f for f in os.listdir(val_class_dir) if f.endswith(('.jpg', '.png', '.jpeg'))]
    # Take up to 20 images per class (to keep the confusion matrix computation reasonable)
    sample_count = min(20, len(class_images))
    if sample_count > 0:
        for img_file in random.sample(class_images, sample_count):
            test_data.append((cls_idx, cls_name, os.path.join(val_class_dir, img_file)))

# Run predictions
true_labels, pred_labels = predict_batch(trained_model, test_data, class_names)

# Find unique classes in the subset
unique_true_classes = sorted(set(true_labels))
unique_pred_classes = sorted(set(pred_labels))
unique_classes = sorted(set(unique_true_classes + unique_pred_classes))

# Generate confusion matrix for only the classes that appear in our sample
cm = confusion_matrix(true_labels, pred_labels, labels=unique_classes)

# Create display labels for only those classes present in our sample
display_labels = [class_names[i] for i in unique_classes]

# Plot confusion matrix
plt.figure(figsize=(15, 15))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=display_labels)
disp.plot(xticks_rotation='vertical', cmap='Blues')
plt.title('Confusion Matrix (Subset of Classes)')
plt.tight_layout()
plt.show()

# Calculate per-class metrics
from sklearn.metrics import classification_report

# Create a target_names list that includes only the classes present in our sample
target_names = [class_names[i] for i in unique_classes]

report = classification_report(true_labels, pred_labels, labels=unique_classes, 
                              target_names=target_names, output_dict=True)
report_df = pd.DataFrame(report).transpose()
print("Classification Report:")
display(report_df)
# Out:
# Predicting:   0%|          | 0/1520 [00:00<?, ?it/s]
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apple/Apple Red Delicious 1_r_285_100.jpg: 224x224 apple 1.00, grapefruit 0.00, granadilla 0.00, nectarine 0.00, passion 0.00, 4.0ms
# Speed: 1.5ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apple/Apple Red Delicious 1_r_285_100.jpg: 224x224 apple 1.00, grapefruit 0.00, granadilla 0.00, nectarine 0.00, passion 0.00, 4.0ms
# Speed: 1.5ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apple/Apple 8_r2_252_100.jpg: 224x224 apple 1.00, tomato 0.00, quince 0.00, pear 0.00, mango 0.00, 2.7ms
# Speed: 1.0ms preprocess, 2.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apple/Apple 7_r0_47_100.jpg: 224x224 apple 1.00, pear 0.00, nut 0.00, tomato 0.00, cucumber 0.00, 3.9ms
# Speed: 1.2ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apple/Apple 8_r2_252_100.jpg: 224x224 apple 1.00, tomato 0.00, quince 0.00, pear 0.00, mango 0.00, 2.7ms
# Speed: 1.0ms preprocess, 2.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apple/Apple 7_r0_47_100.jpg: 224x224 apple 1.00, pear 0.00, nut 0.00, tomato 0.00, cucumber 0.00, 3.9ms
# Speed: 1.2ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apple/Apple Golden 2_r_300_100.jpg: 224x224 apple 1.00, grapefruit 0.00, pear 0.00, tomato 0.00, kohlrabi 0.00, 3.1ms
# Speed: 1.1ms preprocess, 3.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apple/Apple Red 3_39_100.jpg: 224x224 apple 1.00, peach 0.00, nectarine 0.00, pomegranate 0.00, pear 0.00, 3.0ms
# Speed: 1.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apple/Apple Golden 2_r_300_100.jpg: 224x224 apple 1.00, grapefruit 0.00, pear 0.00, tomato 0.00, kohlrabi 0.00, 3.1ms
# Speed: 1.1ms preprocess, 3.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apple/Apple Red 3_39_100.jpg: 224x224 apple 1.00, peach 0.00, nectarine 0.00, pomegranate 0.00, pear 0.00, 3.0ms
# Speed: 1.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apple/Apple Red 1_r_159_100.jpg: 224x224 apple 1.00, nectarine 0.00, pomegranate 0.00, pear 0.00, peach 0.00, 2.9ms
# Speed: 1.0ms preprocess, 2.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apple/Apple Red Yellow 1_7_100.jpg: 224x224 apple 1.00, peach 0.00, pear 0.00, nectarine 0.00, cherry 0.00, 3.3ms
# Speed: 1.1ms preprocess, 3.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apple/Apple Red 1_r_159_100.jpg: 224x224 apple 1.00, nectarine 0.00, pomegranate 0.00, pear 0.00, peach 0.00, 2.9ms
# Speed: 1.0ms preprocess, 2.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apple/Apple Red Yellow 1_7_100.jpg: 224x224 apple 1.00, peach 0.00, pear 0.00, nectarine 0.00, cherry 0.00, 3.3ms
# Speed: 1.1ms preprocess, 3.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apple/Apple worm 1_r1_51_100.jpg: 224x224 apple 1.00, tomato 0.00, nectarine 0.00, quince 0.00, cucumber 0.00, 2.7ms
# Speed: 0.9ms preprocess, 2.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apple/Apple Red Yellow 2_r_48_100.jpg: 224x224 apple 1.00, tomato 0.00, pepper 0.00, cucumber 0.00, quince 0.00, 2.8ms
# Speed: 0.9ms preprocess, 2.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apple/Apple worm 1_r1_51_100.jpg: 224x224 apple 1.00, tomato 0.00, nectarine 0.00, quince 0.00, cucumber 0.00, 2.7ms
# Speed: 0.9ms preprocess, 2.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apple/Apple Red Yellow 2_r_48_100.jpg: 224x224 apple 1.00, tomato 0.00, pepper 0.00, cucumber 0.00, quince 0.00, 2.8ms
# Speed: 0.9ms preprocess, 2.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apple/Apple 18_r1_201_100.jpg: 224x224 apple 1.00, tomato 0.00, nut 0.00, pear 0.00, granadilla 0.00, 3.5ms
# Speed: 1.2ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apple/Apple Braeburn 1_60_100.jpg: 224x224 apple 1.00, nectarine 0.00, pomegranate 0.00, cherry 0.00, strawberry 0.00, 4.0ms
# Speed: 1.2ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apple/Apple 18_r1_201_100.jpg: 224x224 apple 1.00, tomato 0.00, nut 0.00, pear 0.00, granadilla 0.00, 3.5ms
# Speed: 1.2ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apple/Apple Braeburn 1_60_100.jpg: 224x224 apple 1.00, nectarine 0.00, pomegranate 0.00, cherry 0.00, strawberry 0.00, 4.0ms
# Speed: 1.2ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apple/Apple 9_r1_80_100.jpg: 224x224 apple 1.00, pear 0.00, nectarine 0.00, quince 0.00, cherry 0.00, 3.3ms
# Speed: 0.9ms preprocess, 3.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apple/Apple 13_r2_228_100.jpg: 224x224 apple 1.00, quince 0.00, tomato 0.00, cucumber 0.00, pear 0.00, 3.0ms
# Speed: 0.9ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apple/Apple 9_r1_80_100.jpg: 224x224 apple 1.00, pear 0.00, nectarine 0.00, quince 0.00, cherry 0.00, 3.3ms
# Speed: 0.9ms preprocess, 3.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apple/Apple 13_r2_228_100.jpg: 224x224 apple 1.00, quince 0.00, tomato 0.00, cucumber 0.00, pear 0.00, 3.0ms
# Speed: 0.9ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apple/Apple Granny Smith 1_201_100.jpg: 224x224 apple 1.00, pear 0.00, lemon 0.00, onion 0.00, tamarillo 0.00, 3.0ms
# Speed: 1.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apple/Apple 10_r1_257_100.jpg: 224x224 apple 1.00, quince 0.00, tomato 0.00, nectarine 0.00, pear 0.00, 3.0ms
# Speed: 0.9ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apple/Apple Granny Smith 1_201_100.jpg: 224x224 apple 1.00, pear 0.00, lemon 0.00, onion 0.00, tamarillo 0.00, 3.0ms
# Speed: 1.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apple/Apple 10_r1_257_100.jpg: 224x224 apple 1.00, quince 0.00, tomato 0.00, nectarine 0.00, pear 0.00, 3.0ms
# Speed: 0.9ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apple/Apple 9_r2_35_100.jpg: 224x224 apple 1.00, tomato 0.00, quince 0.00, cherimoya 0.00, pear 0.00, 2.6ms
# Speed: 1.1ms preprocess, 2.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apple/Apple 8_r1_8_100.jpg: 224x224 apple 1.00, tomato 0.00, quince 0.00, pear 0.00, nectarine 0.00, 3.9ms
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apple/Apple 9_r2_35_100.jpg: 224x224 apple 1.00, tomato 0.00, quince 0.00, cherimoya 0.00, pear 0.00, 2.6ms
# Speed: 1.1ms preprocess, 2.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apple/Apple 8_r1_8_100.jpg: 224x224 apple 1.00, tomato 0.00, quince 0.00, pear 0.00, nectarine 0.00, 3.9ms
# Speed: 3.7ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Speed: 3.7ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apple/Apple 10_r0_299_100.jpg: 224x224 apple 1.00, nectarine 0.00, pear 0.00, quince 0.00, onion 0.00, 3.9ms
# Speed: 1.8ms preprocess, 3.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apple/Apple 10_r0_299_100.jpg: 224x224 apple 1.00, nectarine 0.00, pear 0.00, quince 0.00, onion 0.00, 3.9ms
# Speed: 1.8ms preprocess, 3.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apple/Apple 13_r1_67_100.jpg: 224x224 apple 1.00, peach 0.00, quince 0.00, nut 0.00, potato 0.00, 3.5ms
# Speed: 7.4ms preprocess, 3.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apple/Apple 13_r1_197_100.jpg: 224x224 apple 1.00, cucumber 0.00, quince 0.00, nectarine 0.00, potato 0.00, 4.3ms
# Speed: 2.2ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apple/Apple 13_r1_67_100.jpg: 224x224 apple 1.00, peach 0.00, quince 0.00, nut 0.00, potato 0.00, 3.5ms
# Speed: 7.4ms preprocess, 3.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apple/Apple 13_r1_197_100.jpg: 224x224 apple 1.00, cucumber 0.00, quince 0.00, nectarine 0.00, potato 0.00, 4.3ms
# Speed: 2.2ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apricot/Apricot 1_277_100.jpg: 224x224 apricot 1.00, peach 0.00, clementine 0.00, kumquats 0.00, cucumber 0.00, 3.2ms
# Speed: 13.4ms preprocess, 3.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apricot/Apricot 1_277_100.jpg: 224x224 apricot 1.00, peach 0.00, clementine 0.00, kumquats 0.00, cucumber 0.00, 3.2ms
# Speed: 13.4ms preprocess, 3.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apricot/Apricot 1_r_73_100.jpg: 224x224 apricot 1.00, grape 0.00, kaki 0.00, clementine 0.00, apple 0.00, 3.3ms
# Speed: 1.5ms preprocess, 3.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apricot/Apricot 1_r_129_100.jpg: 224x224 apricot 1.00, cucumber 0.00, kumquats 0.00, peach 0.00, lemon 0.00, 3.7ms
# Speed: 1.2ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apricot/Apricot 1_r_73_100.jpg: 224x224 apricot 1.00, grape 0.00, kaki 0.00, clementine 0.00, apple 0.00, 3.3ms
# Speed: 1.5ms preprocess, 3.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apricot/Apricot 1_r_129_100.jpg: 224x224 apricot 1.00, cucumber 0.00, kumquats 0.00, peach 0.00, lemon 0.00, 3.7ms
# Speed: 1.2ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apricot/Apricot 1_r_114_100.jpg: 224x224 apricot 1.00, cucumber 0.00, apple 0.00, lemon 0.00, peach 0.00, 3.1ms
# Speed: 0.9ms preprocess, 3.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apricot/Apricot 1_242_100.jpg: 224x224 apricot 1.00, kumquats 0.00, cucumber 0.00, kaki 0.00, grape 0.00, 3.7ms
# Speed: 1.0ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apricot/Apricot 1_r_114_100.jpg: 224x224 apricot 1.00, cucumber 0.00, apple 0.00, lemon 0.00, peach 0.00, 3.1ms
# Speed: 0.9ms preprocess, 3.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apricot/Apricot 1_242_100.jpg: 224x224 apricot 1.00, kumquats 0.00, cucumber 0.00, kaki 0.00, grape 0.00, 3.7ms
# Speed: 1.0ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apricot/Apricot 1_r_101_100.jpg: 224x224 apricot 1.00, peach 0.00, clementine 0.00, cucumber 0.00, kumquats 0.00, 3.8ms
# Speed: 1.3ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apricot/Apricot 1_2_100.jpg: 224x224 apricot 1.00, peach 0.00, clementine 0.00, cucumber 0.00, apple 0.00, 3.0ms
# Speed: 1.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apricot/Apricot 1_200_100.jpg: 224x224 apricot 1.00, grape 0.00, kumquats 0.00, apple 0.00, cucumber 0.00, 2.4ms
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apricot/Apricot 1_r_101_100.jpg: 224x224 apricot 1.00, peach 0.00, clementine 0.00, cucumber 0.00, kumquats 0.00, 3.8ms
# Speed: 1.3ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apricot/Apricot 1_2_100.jpg: 224x224 apricot 1.00, peach 0.00, clementine 0.00, cucumber 0.00, apple 0.00, 3.0ms
# Speed: 1.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apricot/Apricot 1_200_100.jpg: 224x224 apricot 1.00, grape 0.00, kumquats 0.00, apple 0.00, cucumber 0.00, 2.4ms
# Speed: 0.9ms preprocess, 2.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apricot/Apricot 1_r_112_100.jpg: 224x224 apricot 1.00, cucumber 0.00, peach 0.00, lemon 0.00, nectarine 0.00, 3.4ms
# Speed: 1.1ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# Speed: 0.9ms preprocess, 2.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apricot/Apricot 1_r_112_100.jpg: 224x224 apricot 1.00, cucumber 0.00, peach 0.00, lemon 0.00, nectarine 0.00, 3.4ms
# Speed: 1.1ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apricot/Apricot 1_r_37_100.jpg: 224x224 apricot 1.00, grape 0.00, pepper 0.00, nectarine 0.00, peach 0.00, 3.3ms
# Speed: 0.9ms preprocess, 3.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apricot/Apricot 1_r_39_100.jpg: 224x224 apricot 1.00, grape 0.00, pepper 0.00, nectarine 0.00, apple 0.00, 2.9ms
# Speed: 1.1ms preprocess, 2.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apricot/Apricot 1_r_37_100.jpg: 224x224 apricot 1.00, grape 0.00, pepper 0.00, nectarine 0.00, peach 0.00, 3.3ms
# Speed: 0.9ms preprocess, 3.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apricot/Apricot 1_r_39_100.jpg: 224x224 apricot 1.00, grape 0.00, pepper 0.00, nectarine 0.00, apple 0.00, 2.9ms
# Speed: 1.1ms preprocess, 2.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apricot/Apricot 1_98_100.jpg: 224x224 apricot 1.00, kumquats 0.00, peach 0.00, kaki 0.00, lemon 0.00, 2.6ms
# Speed: 1.0ms preprocess, 2.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apricot/Apricot 1_r_25_100.jpg: 224x224 apricot 1.00, grape 0.00, apple 0.00, pepper 0.00, nectarine 0.00, 3.3ms
# Speed: 1.0ms preprocess, 3.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apricot/Apricot 1_98_100.jpg: 224x224 apricot 1.00, kumquats 0.00, peach 0.00, kaki 0.00, lemon 0.00, 2.6ms
# Speed: 1.0ms preprocess, 2.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apricot/Apricot 1_r_25_100.jpg: 224x224 apricot 1.00, grape 0.00, apple 0.00, pepper 0.00, nectarine 0.00, 3.3ms
# Speed: 1.0ms preprocess, 3.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apricot/Apricot 1_146_100.jpg: 224x224 apricot 1.00, peach 0.00, cucumber 0.00, apple 0.00, nectarine 0.00, 3.0ms
# Speed: 0.9ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apricot/Apricot 1_243_100.jpg: 224x224 apricot 1.00, kumquats 0.00, cucumber 0.00, kaki 0.00, peach 0.00, 3.0ms
# Speed: 0.9ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apricot/Apricot 1_146_100.jpg: 224x224 apricot 1.00, peach 0.00, cucumber 0.00, apple 0.00, nectarine 0.00, 3.0ms
# Speed: 0.9ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apricot/Apricot 1_243_100.jpg: 224x224 apricot 1.00, kumquats 0.00, cucumber 0.00, kaki 0.00, peach 0.00, 3.0ms
# Speed: 0.9ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apricot/Apricot 1_85_100.jpg: 224x224 apricot 1.00, kumquats 0.00, peach 0.00, kaki 0.00, clementine 0.00, 2.9ms
# Speed: 0.9ms preprocess, 2.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apricot/Apricot 1_r_273_100.jpg: 224x224 apricot 1.00, kumquats 0.00, grape 0.00, cucumber 0.00, clementine 0.00, 2.9ms
# Speed: 1.0ms preprocess, 2.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apricot/Apricot 1_85_100.jpg: 224x224 apricot 1.00, kumquats 0.00, peach 0.00, kaki 0.00, clementine 0.00, 2.9ms
# Speed: 0.9ms preprocess, 2.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apricot/Apricot 1_r_273_100.jpg: 224x224 apricot 1.00, kumquats 0.00, grape 0.00, cucumber 0.00, clementine 0.00, 2.9ms
# Speed: 1.0ms preprocess, 2.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apricot/Apricot 1_r_66_100.jpg: 224x224 apricot 1.00, grape 0.00, kaki 0.00, apple 0.00, tomato 0.00, 2.7ms
# Speed: 1.0ms preprocess, 2.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apricot/Apricot 1_r_21_100.jpg: 224x224 apricot 1.00, grape 0.00, apple 0.00, pepper 0.00, pear 0.00, 2.9ms
# Speed: 1.1ms preprocess, 2.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apricot/Apricot 1_r_66_100.jpg: 224x224 apricot 1.00, grape 0.00, kaki 0.00, apple 0.00, tomato 0.00, 2.7ms
# Speed: 1.0ms preprocess, 2.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apricot/Apricot 1_r_21_100.jpg: 224x224 apricot 1.00, grape 0.00, apple 0.00, pepper 0.00, pear 0.00, 2.9ms
# Speed: 1.1ms preprocess, 2.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apricot/Apricot 1_r_322_100.jpg: 224x224 apricot 1.00, peach 0.00, grape 0.00, cucumber 0.00, pomegranate 0.00, 2.6ms
# Speed: 0.8ms preprocess, 2.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/avocado/Avocado Green 1_r2_187_100.jpg: 224x224 avocado 1.00, cucumber 0.00, mango 0.00, apple 0.00, pear 0.00, 2.6ms
# Speed: 0.8ms preprocess, 2.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/avocado/Avocado 1_r_283_100.jpg: 224x224 avocado 1.00, papaya 0.00, pear 0.00, nut 0.00, cucumber 0.00, 2.4ms
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/apricot/Apricot 1_r_322_100.jpg: 224x224 apricot 1.00, peach 0.00, grape 0.00, cucumber 0.00, pomegranate 0.00, 2.6ms
# Speed: 0.8ms preprocess, 2.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/avocado/Avocado Green 1_r2_187_100.jpg: 224x224 avocado 1.00, cucumber 0.00, mango 0.00, apple 0.00, pear 0.00, 2.6ms
# Speed: 0.8ms preprocess, 2.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/avocado/Avocado 1_r_283_100.jpg: 224x224 avocado 1.00, papaya 0.00, pear 0.00, nut 0.00, cucumber 0.00, 2.4ms
# Speed: 0.9ms preprocess, 2.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/avocado/Avocado 1_6_100.jpg: 224x224 avocado 1.00, papaya 0.00, pear 0.00, mango 0.00, cucumber 0.00, 2.7ms
# Speed: 0.8ms preprocess, 2.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/avocado/Avocado 1_196_100.jpg: 224x224 avocado 1.00, pear 0.00, papaya 0.00, cucumber 0.00, nut 0.00, 2.4ms
# Speed: 0.9ms preprocess, 2.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/avocado/Avocado 1_6_100.jpg: 224x224 avocado 1.00, papaya 0.00, pear 0.00, mango 0.00, cucumber 0.00, 2.7ms
# Speed: 0.8ms preprocess, 2.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/avocado/Avocado 1_196_100.jpg: 224x224 avocado 1.00, pear 0.00, papaya 0.00, cucumber 0.00, nut 0.00, 2.4ms
# Speed: 0.9ms preprocess, 2.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/avocado/Avocado Green 1_r0_12_100.jpg: 224x224 avocado 1.00, cucumber 0.00, mango 0.00, pear 0.00, gooseberry 0.00, 2.6ms
# Speed: 0.8ms preprocess, 2.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# Speed: 0.9ms preprocess, 2.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/avocado/Avocado Green 1_r0_12_100.jpg: 224x224 avocado 1.00, cucumber 0.00, mango 0.00, pear 0.00, gooseberry 0.00, 2.6ms
# Speed: 0.8ms preprocess, 2.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/avocado/Avocado Green 1_r1_128_100.jpg: 224x224 avocado 1.00, cucumber 0.00, mango 0.00, apple 0.00, gooseberry 0.00, 3.3ms
# Speed: 0.9ms preprocess, 3.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/avocado/Avocado 1_112_100.jpg: 224x224 avocado 1.00, pear 0.00, papaya 0.00, beetroot 0.00, cucumber 0.00, 3.1ms
# Speed: 1.2ms preprocess, 3.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/avocado/Avocado Green 1_r1_128_100.jpg: 224x224 avocado 1.00, cucumber 0.00, mango 0.00, apple 0.00, gooseberry 0.00, 3.3ms
# Speed: 0.9ms preprocess, 3.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/avocado/Avocado 1_112_100.jpg: 224x224 avocado 1.00, pear 0.00, papaya 0.00, beetroot 0.00, cucumber 0.00, 3.1ms
# Speed: 1.2ms preprocess, 3.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/avocado/Avocado Black 1_r0_192_100.jpg: 224x224 avocado 1.00, salak 0.00, nut 0.00, cucumber 0.00, pear 0.00, 3.1ms
# Speed: 0.9ms preprocess, 3.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/avocado/Avocado Black 1_r2_134_100.jpg: 224x224 avocado 1.00, cucumber 0.00, nut 0.00, salak 0.00, blueberry 0.00, 2.6ms
# Speed: 1.4ms preprocess, 2.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/avocado/Avocado Black 1_r0_192_100.jpg: 224x224 avocado 1.00, salak 0.00, nut 0.00, cucumber 0.00, pear 0.00, 3.1ms
# Speed: 0.9ms preprocess, 3.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/avocado/Avocado Black 1_r2_134_100.jpg: 224x224 avocado 1.00, cucumber 0.00, nut 0.00, salak 0.00, blueberry 0.00, 2.6ms
# Speed: 1.4ms preprocess, 2.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/avocado/Avocado Black 1_r1_97_100.jpg: 224x224 avocado 1.00, cucumber 0.00, nut 0.00, quince 0.00, pear 0.00, 3.1ms
# Speed: 0.9ms preprocess, 3.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/avocado/Avocado ripe 1_213_100.jpg: 224x224 avocado 1.00, cocos 0.00, beetroot 0.00, cucumber 0.00, pear 0.00, 3.3ms
# Speed: 1.1ms preprocess, 3.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/avocado/Avocado Black 1_r1_97_100.jpg: 224x224 avocado 1.00, cucumber 0.00, nut 0.00, quince 0.00, pear 0.00, 3.1ms
# Speed: 0.9ms preprocess, 3.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/avocado/Avocado ripe 1_213_100.jpg: 224x224 avocado 1.00, cocos 0.00, beetroot 0.00, cucumber 0.00, pear 0.00, 3.3ms
# Speed: 1.1ms preprocess, 3.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/avocado/Avocado Green 1_r2_71_100.jpg: 224x224 avocado 1.00, cucumber 0.00, mango 0.00, pear 0.00, gooseberry 0.00, 3.2ms
# Speed: 1.0ms preprocess, 3.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/avocado/Avocado Black 1_r1_256_100.jpg: 224x224 avocado 1.00, cucumber 0.00, nut 0.00, salak 0.00, guava 0.00, 3.0ms
# Speed: 0.9ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/avocado/Avocado Green 1_r2_71_100.jpg: 224x224 avocado 1.00, cucumber 0.00, mango 0.00, pear 0.00, gooseberry 0.00, 3.2ms
# Speed: 1.0ms preprocess, 3.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/avocado/Avocado Black 1_r1_256_100.jpg: 224x224 avocado 1.00, cucumber 0.00, nut 0.00, salak 0.00, guava 0.00, 3.0ms
# Speed: 0.9ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/avocado/Avocado Green 1_r1_82_100.jpg: 224x224 avocado 1.00, mango 0.00, cucumber 0.00, cherry 0.00, apple 0.00, 3.1ms
# Speed: 0.9ms preprocess, 3.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/avocado/Avocado Black 1_r2_60_100.jpg: 224x224 avocado 1.00, cucumber 0.00, nut 0.00, melon 0.00, beetroot 0.00, 3.2ms
# Speed: 1.0ms preprocess, 3.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/avocado/Avocado Green 1_r1_82_100.jpg: 224x224 avocado 1.00, mango 0.00, cucumber 0.00, cherry 0.00, apple 0.00, 3.1ms
# Speed: 0.9ms preprocess, 3.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/avocado/Avocado Black 1_r2_60_100.jpg: 224x224 avocado 1.00, cucumber 0.00, nut 0.00, melon 0.00, beetroot 0.00, 3.2ms
# Speed: 1.0ms preprocess, 3.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/avocado/Avocado Black 1_r2_63_100.jpg: 224x224 avocado 1.00, cucumber 0.00, nut 0.00, melon 0.00, blueberry 0.00, 3.0ms
# Speed: 1.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/avocado/Avocado Green 1_r1_6_100.jpg: 224x224 avocado 1.00, mango 0.00, cucumber 0.00, apple 0.00, nut 0.00, 3.2ms
# Speed: 1.0ms preprocess, 3.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/avocado/Avocado Black 1_r2_63_100.jpg: 224x224 avocado 1.00, cucumber 0.00, nut 0.00, melon 0.00, blueberry 0.00, 3.0ms
# Speed: 1.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/avocado/Avocado Green 1_r1_6_100.jpg: 224x224 avocado 1.00, mango 0.00, cucumber 0.00, apple 0.00, nut 0.00, 3.2ms
# Speed: 1.0ms preprocess, 3.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/avocado/Avocado Black 1_r1_0_100.jpg: 224x224 avocado 1.00, cucumber 0.00, nut 0.00, guava 0.00, blueberry 0.00, 2.9ms
# Speed: 0.9ms preprocess, 2.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/avocado/Avocado 1_83_100.jpg: 224x224 avocado 1.00, pear 0.00, papaya 0.00, cucumber 0.00, beetroot 0.00, 3.1ms
# Speed: 1.1ms preprocess, 3.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/avocado/Avocado Black 1_r1_0_100.jpg: 224x224 avocado 1.00, cucumber 0.00, nut 0.00, guava 0.00, blueberry 0.00, 2.9ms
# Speed: 0.9ms preprocess, 2.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/avocado/Avocado 1_83_100.jpg: 224x224 avocado 1.00, pear 0.00, papaya 0.00, cucumber 0.00, beetroot 0.00, 3.1ms
# Speed: 1.1ms preprocess, 3.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/avocado/Avocado Green 1_r2_266_100.jpg: 224x224 avocado 1.00, mango 0.00, cucumber 0.00, gooseberry 0.00, cherry 0.00, 3.2ms
# Speed: 1.0ms preprocess, 3.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/banana/Banana 1_13_100.jpg: 224x224 banana 1.00, cactus fruit 0.00, pear 0.00, caju 0.00, quince 0.00, 3.2ms
# Speed: 0.9ms preprocess, 3.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/avocado/Avocado Green 1_r2_266_100.jpg: 224x224 avocado 1.00, mango 0.00, cucumber 0.00, gooseberry 0.00, cherry 0.00, 3.2ms
# Speed: 1.0ms preprocess, 3.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/banana/Banana 1_13_100.jpg: 224x224 banana 1.00, cactus fruit 0.00, pear 0.00, caju 0.00, quince 0.00, 3.2ms
# Speed: 0.9ms preprocess, 3.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/banana/Banana 1_r_325_100.jpg: 224x224 banana 1.00, cucumber 0.00, beans 0.00, corn 0.00, caju 0.00, 3.0ms
# Speed: 0.8ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/banana/Banana 1_r_13_100.jpg: 224x224 banana 1.00, cucumber 0.00, caju 0.00, cactus fruit 0.00, corn 0.00, 2.8ms
# Speed: 0.9ms preprocess, 2.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/banana/Banana 1_r_325_100.jpg: 224x224 banana 1.00, cucumber 0.00, beans 0.00, corn 0.00, caju 0.00, 3.0ms
# Speed: 0.8ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/banana/Banana 1_r_13_100.jpg: 224x224 banana 1.00, cucumber 0.00, caju 0.00, cactus fruit 0.00, corn 0.00, 2.8ms
# Speed: 0.9ms preprocess, 2.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/banana/Banana 1_r_183_100.jpg: 224x224 banana 1.00, cucumber 0.00, pear 0.00, cactus fruit 0.00, caju 0.00, 2.7ms
# Speed: 0.9ms preprocess, 2.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/banana/Banana 4_r1_310_100.jpg: 224x224 banana 1.00, peach 0.00, pepino 0.00, caju 0.00, quince 0.00, 3.1ms
# Speed: 1.0ms preprocess, 3.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/banana/Banana 1_r_183_100.jpg: 224x224 banana 1.00, cucumber 0.00, pear 0.00, cactus fruit 0.00, caju 0.00, 2.7ms
# Speed: 0.9ms preprocess, 2.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/banana/Banana 4_r1_310_100.jpg: 224x224 banana 1.00, peach 0.00, pepino 0.00, caju 0.00, quince 0.00, 3.1ms
# Speed: 1.0ms preprocess, 3.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/banana/Banana 3_r0_198_100.jpg: 224x224 banana 1.00, cucumber 0.00, quince 0.00, apple 0.00, pepino 0.00, 3.0ms
# Speed: 1.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/banana/Banana Red 1_224_100.jpg: 224x224 banana 1.00, cactus fruit 0.00, pear 0.00, pitahaya 0.00, carambula 0.00, 3.0ms
# Speed: 0.9ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/banana/Banana 3_r0_198_100.jpg: 224x224 banana 1.00, cucumber 0.00, quince 0.00, apple 0.00, pepino 0.00, 3.0ms
# Speed: 1.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/banana/Banana Red 1_224_100.jpg: 224x224 banana 1.00, cactus fruit 0.00, pear 0.00, pitahaya 0.00, carambula 0.00, 3.0ms
# Speed: 0.9ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/banana/Banana Red 1_r_113_100.jpg: 224x224 banana 1.00, pear 0.00, salak 0.00, cactus fruit 0.00, carrot 0.00, 3.0ms
# Speed: 0.8ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/banana/Banana Red 1_54_100.jpg: 224x224 banana 1.00, pear 0.00, carambula 0.00, pitahaya 0.00, redcurrant 0.00, 3.3ms
# Speed: 0.9ms preprocess, 3.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/banana/Banana Red 1_r_113_100.jpg: 224x224 banana 1.00, pear 0.00, salak 0.00, cactus fruit 0.00, carrot 0.00, 3.0ms
# Speed: 0.8ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/banana/Banana Red 1_54_100.jpg: 224x224 banana 1.00, pear 0.00, carambula 0.00, pitahaya 0.00, redcurrant 0.00, 3.3ms
# Speed: 0.9ms preprocess, 3.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/banana/Banana 4_r1_41_100.jpg: 224x224 banana 1.00, cucumber 0.00, quince 0.00, pear 0.00, caju 0.00, 3.1ms
# Speed: 0.9ms preprocess, 3.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/banana/Banana Red 1_268_100.jpg: 224x224 banana 1.00, cactus fruit 0.00, pear 0.00, carambula 0.00, dates 0.00, 3.2ms
# Speed: 1.1ms preprocess, 3.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/banana/Banana 4_r1_41_100.jpg: 224x224 banana 1.00, cucumber 0.00, quince 0.00, pear 0.00, caju 0.00, 3.1ms
# Speed: 0.9ms preprocess, 3.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/banana/Banana Red 1_268_100.jpg: 224x224 banana 1.00, cactus fruit 0.00, pear 0.00, carambula 0.00, dates 0.00, 3.2ms
# Speed: 1.1ms preprocess, 3.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/banana/Banana 1_r_112_100.jpg: 224x224 banana 1.00, cactus fruit 0.00, pepino 0.00, eggplant 0.00, carambula 0.00, 3.4ms
# Speed: 1.1ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/banana/Banana 3_r0_59_100.jpg: 224x224 banana 1.00, cucumber 0.00, beans 0.00, eggplant 0.00, zucchini 0.00, 3.2ms
# Speed: 1.1ms preprocess, 3.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/banana/Banana 1_r_112_100.jpg: 224x224 banana 1.00, cactus fruit 0.00, pepino 0.00, eggplant 0.00, carambula 0.00, 3.4ms
# Speed: 1.1ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/banana/Banana 3_r0_59_100.jpg: 224x224 banana 1.00, cucumber 0.00, beans 0.00, eggplant 0.00, zucchini 0.00, 3.2ms
# Speed: 1.1ms preprocess, 3.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/banana/Banana Red 1_57_100.jpg: 224x224 banana 1.00, pear 0.00, carambula 0.00, pitahaya 0.00, redcurrant 0.00, 3.2ms
# Speed: 1.2ms preprocess, 3.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/banana/Banana 1_323_100.jpg: 224x224 banana 1.00, cactus fruit 0.00, caju 0.00, pear 0.00, carambula 0.00, 3.0ms
# Speed: 1.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/banana/Banana Red 1_57_100.jpg: 224x224 banana 1.00, pear 0.00, carambula 0.00, pitahaya 0.00, redcurrant 0.00, 3.2ms
# Speed: 1.2ms preprocess, 3.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/banana/Banana 1_323_100.jpg: 224x224 banana 1.00, cactus fruit 0.00, caju 0.00, pear 0.00, carambula 0.00, 3.0ms
# Speed: 1.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/banana/Banana Red 1_r_220_100.jpg: 224x224 banana 1.00, redcurrant 0.00, eggplant 0.00, pomegranate 0.00, granadilla 0.00, 2.5ms
# Speed: 0.8ms preprocess, 2.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/banana/Banana Lady Finger 1_r_55_100.jpg: 224x224 banana 1.00, beans 0.00, pear 0.00, caju 0.00, cactus fruit 0.00, 3.0ms
# Speed: 1.1ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/banana/Banana Red 1_r_220_100.jpg: 224x224 banana 1.00, redcurrant 0.00, eggplant 0.00, pomegranate 0.00, granadilla 0.00, 2.5ms
# Speed: 0.8ms preprocess, 2.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/banana/Banana Lady Finger 1_r_55_100.jpg: 224x224 banana 1.00, beans 0.00, pear 0.00, caju 0.00, cactus fruit 0.00, 3.0ms
# Speed: 1.1ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/banana/Banana Red 1_182_100.jpg: 224x224 banana 1.00, pear 0.00, cactus fruit 0.00, eggplant 0.00, pitahaya 0.00, 2.9ms
# Speed: 1.0ms preprocess, 2.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/banana/Banana Lady Finger 1_108_100.jpg: 224x224 banana 1.00, pear 0.00, caju 0.00, carambula 0.00, quince 0.00, 3.4ms
# Speed: 1.0ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/banana/Banana Red 1_182_100.jpg: 224x224 banana 1.00, pear 0.00, cactus fruit 0.00, eggplant 0.00, pitahaya 0.00, 2.9ms
# Speed: 1.0ms preprocess, 2.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/banana/Banana Lady Finger 1_108_100.jpg: 224x224 banana 1.00, pear 0.00, caju 0.00, carambula 0.00, quince 0.00, 3.4ms
# Speed: 1.0ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/banana/Banana Red 1_76_100.jpg: 224x224 banana 1.00, pitahaya 0.00, cactus fruit 0.00, carambula 0.00, redcurrant 0.00, 3.2ms
# Speed: 0.9ms preprocess, 3.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/beans/Beans 1_r1_65_100.jpg: 224x224 beans 1.00, blackberrie 0.00, apple 0.00, granadilla 0.00, banana 0.00, 3.2ms
# Speed: 0.9ms preprocess, 3.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# ...
# Speed: 1.6ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/watermelon/Watermelon 1_80_100.jpg: 224x224 watermelon 1.00, cantaloupe 0.00, pear 0.00, corn 0.00, melon 0.00, 3.9ms
# Speed: 2.0ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/watermelon/Watermelon 1_r_214_100.jpg: 224x224 watermelon 1.00, cantaloupe 0.00, grape 0.00, pear 0.00, potato 0.00, 3.8ms
# Speed: 1.6ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/watermelon/Watermelon 1_80_100.jpg: 224x224 watermelon 1.00, cantaloupe 0.00, pear 0.00, corn 0.00, melon 0.00, 3.9ms
# Speed: 2.0ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/watermelon/Watermelon 1_r_255_100.jpg: 224x224 watermelon 1.00, pear 0.00, melon 0.00, cantaloupe 0.00, grape 0.00, 3.5ms
# Speed: 1.2ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/watermelon/Watermelon 1_r_255_100.jpg: 224x224 watermelon 1.00, pear 0.00, melon 0.00, cantaloupe 0.00, grape 0.00, 3.5ms
# Speed: 1.2ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/watermelon/Watermelon 1_34_100.jpg: 224x224 watermelon 1.00, cantaloupe 0.00, apple 0.00, melon 0.00, pear 0.00, 3.4ms
# Speed: 1.4ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/watermelon/Watermelon 1_r_297_100.jpg: 224x224 watermelon 1.00, corn 0.00, melon 0.00, onion 0.00, cantaloupe 0.00, 3.3ms
# Speed: 1.1ms preprocess, 3.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/watermelon/Watermelon 1_34_100.jpg: 224x224 watermelon 1.00, cantaloupe 0.00, apple 0.00, melon 0.00, pear 0.00, 3.4ms
# Speed: 1.4ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/watermelon/Watermelon 1_r_297_100.jpg: 224x224 watermelon 1.00, corn 0.00, melon 0.00, onion 0.00, cantaloupe 0.00, 3.3ms
# Speed: 1.1ms preprocess, 3.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/zucchini/Zucchini 1_r0_294_100.jpg: 224x224 zucchini 1.00, cucumber 0.00, corn 0.00, banana 0.00, cactus fruit 0.00, 3.8ms
# Speed: 1.3ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/zucchini/Zucchini dark 1_r0_207_100.jpg: 224x224 zucchini 1.00, cucumber 0.00, pepper 0.00, eggplant 0.00, banana 0.00, 3.5ms
# Speed: 1.7ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/zucchini/Zucchini 1_r0_294_100.jpg: 224x224 zucchini 1.00, cucumber 0.00, corn 0.00, banana 0.00, cactus fruit 0.00, 3.8ms
# Speed: 1.3ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/zucchini/Zucchini dark 1_r0_207_100.jpg: 224x224 zucchini 1.00, cucumber 0.00, pepper 0.00, eggplant 0.00, banana 0.00, 3.5ms
# Speed: 1.7ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/zucchini/Zucchini dark 1_r0_42_100.jpg: 224x224 zucchini 1.00, eggplant 0.00, cucumber 0.00, pepper 0.00, mulberry 0.00, 2.8ms
# Speed: 1.2ms preprocess, 2.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/zucchini/Zucchini 1_r0_142_100.jpg: 224x224 zucchini 1.00, cucumber 0.00, corn 0.00, cactus fruit 0.00, banana 0.00, 5.8ms
# Speed: 1.3ms preprocess, 5.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/zucchini/Zucchini dark 1_r0_42_100.jpg: 224x224 zucchini 1.00, eggplant 0.00, cucumber 0.00, pepper 0.00, mulberry 0.00, 2.8ms
# Speed: 1.2ms preprocess, 2.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/zucchini/Zucchini 1_r0_142_100.jpg: 224x224 zucchini 1.00, cucumber 0.00, corn 0.00, cactus fruit 0.00, banana 0.00, 5.8ms
# Speed: 1.3ms preprocess, 5.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/zucchini/Zucchini dark 1_r0_123_100.jpg: 224x224 zucchini 1.00, cucumber 0.00, eggplant 0.00, banana 0.00, mulberry 0.00, 3.4ms
# Speed: 7.5ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/zucchini/Zucchini dark 1_r0_51_100.jpg: 224x224 zucchini 1.00, eggplant 0.00, pepper 0.00, cucumber 0.00, banana 0.00, 3.6ms
# Speed: 1.3ms preprocess, 3.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/zucchini/Zucchini dark 1_r0_123_100.jpg: 224x224 zucchini 1.00, cucumber 0.00, eggplant 0.00, banana 0.00, mulberry 0.00, 3.4ms
# Speed: 7.5ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/zucchini/Zucchini dark 1_r0_51_100.jpg: 224x224 zucchini 1.00, eggplant 0.00, pepper 0.00, cucumber 0.00, banana 0.00, 3.6ms
# Speed: 1.3ms preprocess, 3.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/zucchini/Zucchini 1_r0_204_100.jpg: 224x224 zucchini 1.00, cucumber 0.00, corn 0.00, banana 0.00, cactus fruit 0.00, 3.9ms
# Speed: 4.2ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/zucchini/Zucchini 1_r0_204_100.jpg: 224x224 zucchini 1.00, cucumber 0.00, corn 0.00, banana 0.00, cactus fruit 0.00, 3.9ms
# Speed: 4.2ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/zucchini/Zucchini dark 1_r0_293_100.jpg: 224x224 zucchini 1.00, cucumber 0.00, eggplant 0.00, pepper 0.00, mulberry 0.00, 4.6ms
# Speed: 6.7ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/zucchini/Zucchini dark 1_r0_293_100.jpg: 224x224 zucchini 1.00, cucumber 0.00, eggplant 0.00, pepper 0.00, mulberry 0.00, 4.6ms
# Speed: 6.7ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/zucchini/Zucchini 1_r0_40_100.jpg: 224x224 zucchini 1.00, banana 0.00, corn 0.00, cactus fruit 0.00, kohlrabi 0.00, 4.0ms
# Speed: 7.9ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/zucchini/Zucchini 1_r0_40_100.jpg: 224x224 zucchini 1.00, banana 0.00, corn 0.00, cactus fruit 0.00, kohlrabi 0.00, 4.0ms
# Speed: 7.9ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/zucchini/Zucchini dark 1_r0_78_100.jpg: 224x224 zucchini 1.00, cucumber 0.00, eggplant 0.00, corn 0.00, mulberry 0.00, 4.2ms
# Speed: 9.2ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/zucchini/Zucchini 1_r0_114_100.jpg: 224x224 zucchini 1.00, corn 0.00, cucumber 0.00, banana 0.00, cactus fruit 0.00, 3.8ms
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/zucchini/Zucchini dark 1_r0_78_100.jpg: 224x224 zucchini 1.00, cucumber 0.00, eggplant 0.00, corn 0.00, mulberry 0.00, 4.2ms
# Speed: 9.2ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/zucchini/Zucchini 1_r0_114_100.jpg: 224x224 zucchini 1.00, corn 0.00, cucumber 0.00, banana 0.00, cactus fruit 0.00, 3.8ms
# Speed: 2.6ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/zucchini/Zucchini 1_r0_310_100.jpg: 224x224 zucchini 1.00, cucumber 0.00, corn 0.00, banana 0.00, cactus fruit 0.00, 3.5ms
# Speed: 4.4ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Speed: 2.6ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/zucchini/Zucchini 1_r0_310_100.jpg: 224x224 zucchini 1.00, cucumber 0.00, corn 0.00, banana 0.00, cactus fruit 0.00, 3.5ms
# Speed: 4.4ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/zucchini/Zucchini dark 1_r0_7_100.jpg: 224x224 zucchini 1.00, eggplant 0.00, cucumber 0.00, pepper 0.00, banana 0.00, 3.7ms
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/zucchini/Zucchini dark 1_r0_7_100.jpg: 224x224 zucchini 1.00, eggplant 0.00, cucumber 0.00, pepper 0.00, banana 0.00, 3.7ms
# Speed: 1.5ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# Speed: 1.5ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/zucchini/Zucchini 1_r0_269_100.jpg: 224x224 zucchini 1.00, corn 0.00, cucumber 0.00, banana 0.00, cactus fruit 0.00, 3.8ms
# Speed: 1.2ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/zucchini/Zucchini dark 1_r0_81_100.jpg: 224x224 zucchini 1.00, cucumber 0.00, eggplant 0.00, mulberry 0.00, corn 0.00, 3.3ms
# Speed: 0.9ms preprocess, 3.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/zucchini/Zucchini 1_r0_269_100.jpg: 224x224 zucchini 1.00, corn 0.00, cucumber 0.00, banana 0.00, cactus fruit 0.00, 3.8ms
# Speed: 1.2ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/zucchini/Zucchini dark 1_r0_81_100.jpg: 224x224 zucchini 1.00, cucumber 0.00, eggplant 0.00, mulberry 0.00, corn 0.00, 3.3ms
# Speed: 0.9ms preprocess, 3.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/zucchini/Zucchini dark 1_r0_148_100.jpg: 224x224 zucchini 1.00, cucumber 0.00, eggplant 0.00, corn 0.00, mulberry 0.00, 3.3ms
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/zucchini/Zucchini dark 1_r0_148_100.jpg: 224x224 zucchini 1.00, cucumber 0.00, eggplant 0.00, corn 0.00, mulberry 0.00, 3.3ms
# Speed: 1.1ms preprocess, 3.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# Speed: 1.1ms preprocess, 3.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/zucchini/Zucchini 1_r0_124_100.jpg: 224x224 zucchini 1.00, cucumber 0.00, corn 0.00, banana 0.00, pear 0.00, 3.5ms
# Speed: 5.5ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/zucchini/Zucchini dark 1_r0_275_100.jpg: 224x224 zucchini 1.00, cucumber 0.00, eggplant 0.00, mulberry 0.00, corn 0.00, 3.4ms
# Speed: 1.2ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/zucchini/Zucchini 1_r0_124_100.jpg: 224x224 zucchini 1.00, cucumber 0.00, corn 0.00, banana 0.00, pear 0.00, 3.5ms
# Speed: 5.5ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/zucchini/Zucchini dark 1_r0_275_100.jpg: 224x224 zucchini 1.00, cucumber 0.00, eggplant 0.00, mulberry 0.00, corn 0.00, 3.4ms
# Speed: 1.2ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/zucchini/Zucchini dark 1_r0_119_100.jpg: 224x224 zucchini 1.00, cucumber 0.00, eggplant 0.00, mulberry 0.00, corn 0.00, 3.4ms
# Speed: 1.2ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/zucchini/Zucchini 1_r0_140_100.jpg: 224x224 zucchini 1.00, corn 0.00, cucumber 0.00, cactus fruit 0.00, banana 0.00, 3.4ms
# Speed: 1.2ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/zucchini/Zucchini dark 1_r0_119_100.jpg: 224x224 zucchini 1.00, cucumber 0.00, eggplant 0.00, mulberry 0.00, corn 0.00, 3.4ms
# Speed: 1.2ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fruits_yolo/val/zucchini/Zucchini 1_r0_140_100.jpg: 224x224 zucchini 1.00, corn 0.00, cucumber 0.00, cactus fruit 0.00, banana 0.00, 3.4ms
# Speed: 1.2ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Classification Report:
#               precision  recall  f1-score  support
# apple               1.0     1.0       1.0     20.0
# apricot             1.0     1.0       1.0     20.0
# avocado             1.0     1.0       1.0     20.0
# banana              1.0     1.0       1.0     20.0
# beans               1.0     1.0       1.0     20.0
# ...                 ...     ...       ...      ...
# watermelon          1.0     1.0       1.0     20.0
# zucchini            1.0     1.0       1.0     20.0
# accuracy            1.0     1.0       1.0      1.0
# macro avg           1.0     1.0       1.0   1520.0
# weighted avg        1.0     1.0       1.0   1520.0
#
# [79 rows x 4 columns]

# %% [markdown]
# ## 6. Export and Save the Model
#
# Let's export our trained model for deployment.

# %%
# Export the model to ONNX format for deployment
export_dir = os.path.join("..", "models", "fruits_classifier")
os.makedirs(export_dir, exist_ok=True)

# Copy the best PyTorch model
shutil.copy(best_model_path, os.path.join(export_dir, "best.pt"))

# Export to ONNX format
onnx_path = os.path.join(export_dir, "model.onnx")
try:
    trained_model.export(format="onnx", imgsz=IMG_SIZE)
    print(f"Model exported to ONNX format: {onnx_path}")
except Exception as e:
    print(f"ONNX export failed: {e}")

# Save class names for inference
with open(os.path.join(export_dir, "classes.txt"), "w") as f:
    for class_name in class_names:
        f.write(f"{class_name}\n")

print(f"Model and class names saved to {export_dir}")
print("You can now use this model for inference on new images!")
# Out:
# Ultralytics 8.3.158 🚀 Python-3.13.3 torch-2.7.1+cu126 CPU (AMD Ryzen 7 7735HS with Radeon Graphics)
#
# PyTorch: starting from '../runs/fruits_classification/weights/best.pt' with input shape (1, 3, 224, 224) BCHW and output shape(s) (1, 76) (3.2 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0,<1.18.0', 'onnxruntime-gpu'] not found, attempting AutoUpdate...
#
# PyTorch: starting from '../runs/fruits_classification/weights/best.pt' with input shape (1, 3, 224, 224) BCHW and output shape(s) (1, 76) (3.2 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0,<1.18.0', 'onnxruntime-gpu'] not found, attempting AutoUpdate...
# WARNING ⚠️ Retry 1/2 failed: Command 'uv pip install --no-cache-dir "onnx>=1.12.0,<1.18.0" "onnxruntime-gpu"  --index-strategy=unsafe-best-match --break-system-packages --prerelease=allow' returned non-zero exit status 1.
# WARNING ⚠️ Retry 1/2 failed: Command 'uv pip install --no-cache-dir "onnx>=1.12.0,<1.18.0" "onnxruntime-gpu"  --index-strategy=unsafe-best-match --break-system-packages --prerelease=allow' returned non-zero exit status 1.
# WARNING ⚠️
#
# ONNX: starting export with onnx 1.18.0 opset 19...
# WARNING ⚠️
#
# ONNX: starting export with onnx 1.18.0 opset 19...
# ONNX: slimming with onnxslim 0.1.58...
# ONNX: slimming with onnxslim 0.1.58...
# ONNX: export success ✅ 80.4s, saved as '../runs/fruits_classification/weights/best.onnx' (6.2 MB)
#
# Export complete (80.4s)
# Results saved to /home/kuba/Coding/Uczelnia/fridge_project/runs/fruits_classification/weights
# Predict:         yolo predict task=classify model=../runs/fruits_classification/weights/best.onnx imgsz=224
# Validate:        yolo val task=classify model=../runs/fruits_classification/weights/best.onnx imgsz=224 data=../datasets/fruits_yolo
# Visualize:       https://netron.app
# Model exported to ONNX format: ../models/fruits_classifier/model.onnx
# Model and class names saved to ../models/fruits_classifier
# You can now use this model for inference on new images!
# ONNX: export success ✅ 80.4s, saved as '../runs/fruits_classification/weights/best.onnx' (6.2 MB)
#
# Export complete (80.4s)
# Results saved to /home/kuba/Coding/Uczelnia/fridge_project/runs/fruits_classification/weights
# Predict:         yolo predict task=classify model=../runs/fruits_classification/weights/best.onnx imgsz=224
# Validate:        yolo val task=classify model=../runs/fruits_classification/weights/best.onnx imgsz=224 data=../datasets/fruits_yolo
# Visualize:       https://netron.app
# Model exported to ONNX format: ../models/fruits_classifier/model.onnx
# Model and class names saved to ../models/fruits_classifier
# You can now use this model for inference on new images!

# %% [markdown]
# ## 7. Example Inference Code
#
# Here's an example of how to use the trained model for inference on new images.

# %%
def classify_fruit(model_path, image_path, class_names):
    """
    Classify a fruit image using the trained model
    
    Args:
        model_path: Path to the trained model
        image_path: Path to the image to classify
        class_names: List of class names
    
    Returns:
        Predicted class name and confidence
    """
    # Load the model
    model = YOLO(model_path)
    
    # Run inference
    results = model(image_path)
    
    # Get top prediction
    probs = results[0].probs.data.tolist()
    pred_class_idx = probs.index(max(probs))
    pred_class = class_names[pred_class_idx]
    confidence = probs[pred_class_idx]
    
    # Get top 3 predictions
    top3_indices = sorted(range(len(probs)), key=lambda i: probs[i], reverse=True)[:3]
    top3_classes = [(class_names[idx], probs[idx]) for idx in top3_indices]
    
    return pred_class, confidence, top3_classes

# Example usage:
# To test this function, you would use:
# pred_class, confidence, top3 = classify_fruit(
#     model_path=os.path.join(export_dir, "best.pt"),
#     image_path="/path/to/your/test/image.jpg",
#     class_names=class_names
# )
# print(f"Predicted class: {pred_class} with confidence {confidence:.2f}")
# print("Top 3 predictions:")
# for cls, prob in top3:
#     print(f"  {cls}: {prob:.2f}")

# %%
# Create a function to display an image with predictions
def display_prediction(model_path, image_path, class_names):
    """
    Classify and display an image with prediction results
    
    Args:
        model_path: Path to the trained model
        image_path: Path to the image to classify
        class_names: List of class names
    """
    # Load the image
    img = Image.open(image_path)
    
    # Make prediction
    pred_class, confidence, top3_classes = classify_fruit(
        model_path=model_path,
        image_path=image_path,
        class_names=class_names
    )
    
    # Create figure
    plt.figure(figsize=(10, 8))
    plt.imshow(img)
    plt.title(f"Predicted: {pred_class} ({confidence:.2f})", fontsize=14, fontweight='bold')
    
    # Display top 3 predictions as text box
    textstr = "\n".join([f"{cls}: {prob:.4f}" for cls, prob in top3_classes])
    props = dict(boxstyle='round', facecolor='wheat', alpha=0.7)
    plt.text(0.05, 0.95, textstr, transform=plt.gca().transAxes, fontsize=12,
            verticalalignment='top', bbox=props)
    
    plt.axis('off')
    plt.tight_layout()
    plt.show()
    
    return pred_class, confidence, top3_classes

# Use the function to display the prediction for the test image
pred_class, confidence, top3 = display_prediction(
    model_path=os.path.join(export_dir, "best.pt"),
    image_path=os.path.join("..", "datasets", "fridge_testing", "1.jpg"),
    class_names=class_names
)

# Print additional information
print(f"Predicted class: {pred_class} with confidence {confidence:.4f}")
print("Top 3 predictions:")
for cls, prob in top3:
    print(f"  {cls}: {prob:.4f}")
# Out:
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fridge_testing/1.jpg: 224x224 pepper 0.69, tomato 0.19, cherry 0.02, pineapple 0.02, walnut 0.02, 3.5ms
# Speed: 13.1ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# image 1/1 /home/kuba/Coding/Uczelnia/fridge_project/fruits/../datasets/fridge_testing/1.jpg: 224x224 pepper 0.69, tomato 0.19, cherry 0.02, pineapple 0.02, walnut 0.02, 3.5ms
# Speed: 13.1ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Predicted class: pepper with confidence 0.6910
# Top 3 predictions:
#   pepper: 0.6910
#   tomato: 0.1905
#   cherry: 0.0246
