# %% [markdown]
# # Data Preparation for YOLO Instance Segmentation
#
# This notebook prepares the food-recognition-2022 dataset for training a YOLOv11n-seg model. We will:
# 1. Load and parse the annotations from the JSON files
# 2. Create the YOLO directory structure
# 3. Convert instance segmentation masks to YOLO format
# 4. Create a dataset.yaml file for training

# %%
# Import required libraries
import os
import json
import shutil
from pathlib import Path
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

# %% [markdown]
# ## Setup Paths

# %%
# Define dataset paths
DATA_ROOT = os.path.join("..", "datasets", "food-recognition-2022")
TRAIN_DIR = os.path.join(DATA_ROOT, "training")
VAL_DIR = os.path.join(DATA_ROOT, "val")
TEST_DIR = os.path.join(DATA_ROOT, "test", "images")

# Create YOLO dataset directory
YOLO_DATASET_DIR = os.path.join("..", "datasets", "yolo_food_dataset")
os.makedirs(YOLO_DATASET_DIR, exist_ok=True)

# Define YOLO directory structure
for split in ["train", "val"]:
    os.makedirs(os.path.join(YOLO_DATASET_DIR, split, "images"), exist_ok=True)
    os.makedirs(os.path.join(YOLO_DATASET_DIR, split, "labels"), exist_ok=True)

# Verify paths
print(f"Training directory: {TRAIN_DIR}")
print(f"Validation directory: {VAL_DIR}")
print(f"YOLO dataset directory: {YOLO_DATASET_DIR}")
# Out:
# Training directory: /home/kuba/Coding/Uczelnia/fridge_project/datasets/food-recognition-2022/training
# Validation directory: /home/kuba/Coding/Uczelnia/fridge_project/datasets/food-recognition-2022/val
# YOLO dataset directory: /home/kuba/Coding/Uczelnia/fridge_project/datasets/yolo_food_dataset

# %% [markdown]
# ## Load Annotations

# %%
# Load annotations from JSON files
def load_annotations(json_path):
    with open(json_path, 'r') as f:
        return json.load(f)

# Load train and validation annotations
train_annotations = load_annotations(os.path.join(TRAIN_DIR, "annotations.json"))
val_annotations = load_annotations(os.path.join(VAL_DIR, "annotations.json"))

# Extract class information and create a class mapping
categories = {cat['id']: cat['name'] for cat in train_annotations['categories']}
class_ids = {cat_id: idx for idx, cat_id in enumerate(categories.keys())}

print(f"Found {len(categories)} categories:")
for cat_id, name in categories.items():
    print(f"  {class_ids[cat_id]}: {name} (original id: {cat_id})")

print(f"\nTraining images: {len(train_annotations['images'])}")
print(f"Validation images: {len(val_annotations['images'])}")
print(f"Training annotations: {len(train_annotations['annotations'])}")
print(f"Validation annotations: {len(val_annotations['annotations'])}")
# Out:
# Found 498 categories:
#   0: bread-wholemeal (original id: 1565)
#   1: jam (original id: 2099)
#   2: water (original id: 2578)
#   3: bread-sourdough (original id: 1556)
#   4: banana (original id: 1154)
#   5: soft-cheese (original id: 1352)
#   6: ham-raw (original id: 1893)
#   7: hard-cheese (original id: 1310)
#   8: cottage-cheese (original id: 1264)
#   9: bread-half-white (original id: 1536)
#   10: coffee-with-caffeine (original id: 2512)
#   11: fruit-salad (original id: 1166)
#   12: pancakes (original id: 2949)
#   13: tea (original id: 2498)
#   14: salmon-smoked (original id: 2973)
#   15: avocado (original id: 1056)
#   16: spring-onion-scallion (original id: 1111)
#   17: ristretto-with-caffeine (original id: 2524)
#   18: ham (original id: 1886)
#   19: egg (original id: 2022)
#   20: bacon-frying (original id: 1915)
#   21: chips-french-fries (original id: 1013)
#   22: juice-apple (original id: 2446)
#   23: chicken (original id: 1788)
#   24: tomato-raw (original id: 1069)
#   25: broccoli (original id: 1085)
#   26: shrimp-boiled (original id: 259)
#   27: beetroot-steamed-without-addition-of-salt (original id: 50)
#   28: carrot-raw (original id: 1078)
#   29: chickpeas (original id: 1143)
#   30: french-salad-dressing (original id: 2743)
#   31: pasta-hornli (original id: 1487)
#   32: sauce-cream (original id: 2730)
#   33: meat-balls (original id: 8025)
#   34: pasta (original id: 1483)
#   35: tomato-sauce (original id: 2738)
#   36: cheese (original id: 1311)
#   37: pear (original id: 1157)
#   38: cashew-nut (original id: 1213)
#   39: almonds (original id: 1210)
#   40: lentils (original id: 1144)
#   41: mixed-vegetables (original id: 1022)
#   42: peanut-butter (original id: 1203)
#   43: apple (original id: 1151)
#   44: blueberries (original id: 1169)
#   45: cucumber (original id: 1061)
#   46: cocoa-powder (original id: 2171)
#   47: greek-yaourt-yahourt-yogourt-ou-yoghourt (original id: 3332)
#   48: maple-syrup-concentrate (original id: 2115)
#   49: buckwheat-grain-peeled (original id: 3181)
#   50: butter (original id: 2053)
#   51: herbal-tea (original id: 2555)
#   52: mayonnaise (original id: 2750)
#   53: soup-vegetable (original id: 2836)
#   54: wine-red (original id: 2618)
#   55: wine-white (original id: 2620)
#   56: green-bean-steamed-without-addition-of-salt (original id: 387)
#   57: sausage (original id: 1924)
#   58: pizza-margherita-baked (original id: 2939)
#   59: salami (original id: 1879)
#   60: mushroom (original id: 1098)
#   61: bread-meat-substitute-lettuce-sauce (original id: 3739)
#   62: tart (original id: 2350)
#   63: tea-verveine (original id: 2543)
#   64: rice (original id: 1468)
#   65: white-coffee-with-caffeine (original id: 2521)
#   66: linseeds (original id: 1222)
#   67: sunflower-seeds (original id: 1208)
#   68: ham-cooked (original id: 1889)
#   69: bell-pepper-red-raw (original id: 1068)
#   70: zucchini (original id: 1070)
#   71: green-asparagus (original id: 1123)
#   72: tartar-sauce (original id: 2751)
#   73: lye-pretzel-soft (original id: 1595)
#   74: cucumber-pickled (original id: 1060)
#   75: curry-vegetarian (original id: 3630)
#   76: yaourt-yahourt-yogourt-ou-yoghourt-natural (original id: 5641)
#   77: soup-of-lentils-dahl-dhal (original id: 3358)
#   78: soup-cream-of-vegetables (original id: 2837)
#   79: balsamic-vinegar (original id: 2815)
#   80: salmon (original id: 1967)
#   81: salt-cake-vegetables-filled (original id: 2923)
#   82: bacon (original id: 1914)
#   83: orange (original id: 1187)
#   84: pasta-noodles (original id: 1494)
#   85: cream (original id: 1376)
#   86: cake-chocolate (original id: 2303)
#   87: pasta-spaghetti (original id: 1505)
#   88: black-olives (original id: 1229)
#   89: parmesan (original id: 1323)
#   90: spaetzle (original id: 1482)
#   91: salad-lambs-ear (original id: 1050)
#   92: salad-leaf-salad-green (original id: 1040)
#   93: potatoes-steamed (original id: 1010)
#   94: white-cabbage (original id: 1094)
#   95: halloumi (original id: 1309)
#   96: beetroot-raw (original id: 1075)
#   97: bread-grain (original id: 1538)
#   98: applesauce-unsweetened-canned (original id: 727)
#   99: cheese-for-raclette (original id: 1327)
#   100: mushrooms (original id: 1102)
#   101: bread-white (original id: 1566)
#   102: curds-natural-with-at-most-10-fidm (original id: 870)
#   103: bagel-without-filling (original id: 1517)
#   104: quiche-with-cheese-baked-with-puff-pastry (original id: 732)
#   105: soup-potato (original id: 2840)
#   106: bouillon-vegetable (original id: 2859)
#   107: beef-sirloin-steak (original id: 1727)
#   108: taboule-prepared-with-couscous (original id: 2967)
#   109: eggplant (original id: 1055)
#   110: bread (original id: 1522)
#   111: turnover-with-meat-small-meat-pie-empanadas (original id: 3399)
#   112: mungbean-sprouts (original id: 1121)
#   113: mozzarella (original id: 1321)
#   114: pasta-penne (original id: 1496)
#   115: lasagne-vegetable-prepared (original id: 3415)
#   116: mandarine (original id: 1180)
#   117: kiwi (original id: 1176)
#   118: french-beans (original id: 1058)
#   119: tartar-meat (original id: 4335)
#   120: spring-roll-fried (original id: 2918)
#   121: pork-chop (original id: 1757)
#   122: caprese-salad-tomato-mozzarella (original id: 2964)
#   123: leaf-spinach (original id: 1032)
#   124: roll-of-half-white-or-white-flour-with-large-void (original id: 1569)
#   125: pasta-ravioli-stuffing (original id: 1500)
#   126: omelette-plain (original id: 2320)
#   127: tuna (original id: 1980)
#   128: dark-chocolate (original id: 2131)
#   129: sauce-savoury (original id: 2711)
#   130: dried-raisins (original id: 1199)
#   131: ice-tea (original id: 2470)
#   132: kaki (original id: 1174)
#   133: macaroon (original id: 2395)
#   134: smoothie (original id: 2461)
#   135: crepe-plain (original id: 2269)
#   136: chicken-nuggets (original id: 1837)
#   137: chili-con-carne-prepared (original id: 2966)
#   138: veggie-burger (original id: 1942)
#   139: cream-spinach (original id: 5792)
#   140: cod (original id: 1958)
#   141: chinese-cabbage (original id: 1086)
#   142: hamburger-bread-meat-ketchup (original id: 2930)
#   143: soup-pumpkin (original id: 2841)
#   144: sushi (original id: 2944)
#   145: chestnuts (original id: 1204)
#   146: coffee-decaffeinated (original id: 2513)
#   147: sauce-soya (original id: 2807)
#   148: balsamic-salad-dressing (original id: 2742)
#   149: pasta-twist (original id: 1506)
#   150: bolognaise-sauce (original id: 2736)
#   151: leek (original id: 1113)
#   152: fajita-bread-only (original id: 3221)
#   153: potato-gnocchi (original id: 1009)
#   154: beef-cut-into-stripes-only-meat (original id: 1731)
#   155: rice-noodles-vermicelli (original id: 1453)
#   156: tea-ginger (original id: 2553)
#   157: tea-green (original id: 2530)
#   158: bread-whole-wheat (original id: 1554)
#   159: onion (original id: 1116)
#   160: garlic (original id: 1112)
#   161: hummus (original id: 2952)
#   162: pizza-with-vegetables-baked (original id: 633)
#   163: beer (original id: 2634)
#   164: glucose-drink-50g (original id: 3080)
#   165: chicken-wing (original id: 1791)
#   166: ratatouille (original id: 1024)
#   167: peanut (original id: 1214)
#   168: high-protein-pasta-made-of-lentils-peas (original id: 8730)
#   169: cauliflower (original id: 1084)
#   170: quiche-with-spinach-baked-with-cake-dough (original id: 733)
#   171: green-olives (original id: 1228)
#   172: brazil-nut (original id: 1218)
#   173: eggplant-caviar (original id: 2991)
#   174: bread-pita (original id: 1547)
#   175: pasta-wholemeal (original id: 1513)
#   176: sauce-pesto (original id: 2728)
#   177: oil (original id: 2031)
#   178: couscous (original id: 1455)
#   179: sauce-roast (original id: 2714)
#   180: prosecco (original id: 2607)
#   181: crackers (original id: 2899)
#   182: bread-toast (original id: 1560)
#   183: shrimp-prawn-small (original id: 1985)
#   184: panna-cotta (original id: 1367)
#   185: romanesco (original id: 1090)
#   186: water-with-lemon-juice (original id: 3262)
#   187: espresso-with-caffeine (original id: 2504)
#   188: egg-scrambled-prepared (original id: 3042)
#   189: juice-orange (original id: 2454)
#   190: ice-cubes (original id: 2577)
#   191: braided-white-loaf (original id: 1607)
#   192: emmental-cheese (original id: 1293)
#   193: croissant-wholegrain (original id: 1592)
#   194: hazelnut-chocolate-spread-nutella-ovomaltine-caotina (original id: 2172)
#   195: tomme (original id: 1348)
#   196: water-mineral (original id: 2580)
#   197: hazelnut (original id: 1215)
#   198: bacon-raw (original id: 1917)
#   199: bread-nut (original id: 1545)
#   200: black-forest-tart (original id: 2340)
#   201: soup-miso (original id: 2846)
#   202: peach (original id: 1190)
#   203: figs (original id: 1164)
#   204: beef-filet (original id: 1728)
#   205: mustard-dijon (original id: 2811)
#   206: rice-basmati (original id: 1469)
#   207: mashed-potatoes-prepared-with-full-fat-milk-with-butter (original id: 2935)
#   208: dumplings (original id: 2959)
#   209: pumpkin (original id: 1065)
#   210: swiss-chard (original id: 1120)
#   211: red-cabbage (original id: 1092)
#   212: spinach-raw (original id: 282)
#   213: naan-indien-bread (original id: 3248)
#   214: chicken-curry-cream-coconut-milk-curry-spices-paste (original id: 3100)
#   215: crunch-muesli (original id: 1627)
#   216: biscuits (original id: 2388)
#   217: bread-french-white-flour (original id: 1520)
#   218: meatloaf (original id: 1845)
#   219: fresh-cheese (original id: 1300)
#   220: honey (original id: 2103)
#   221: vegetable-mix-peas-and-carrots (original id: 1019)
#   222: parsley (original id: 2773)
#   223: brownie (original id: 2254)
#   224: dairy-ice-cream (original id: 1402)
#   225: tea-black (original id: 2534)
#   226: carrot-cake (original id: 2333)
#   227: fish-fingers-breaded (original id: 2003)
#   228: salad-dressing (original id: 2741)
#   229: dried-meat (original id: 1853)
#   230: chicken-breast (original id: 1789)
#   231: mixed-salad-chopped-without-sauce (original id: 1026)
#   232: feta (original id: 1294)
#   233: praline (original id: 2073)
#   234: tea-peppermint (original id: 2562)
#   235: walnut (original id: 1212)
#   236: potato-salad-with-mayonnaise-yogurt-dressing (original id: 780)
#   237: kebab-in-pita-bread (original id: 2947)
#   238: kolhrabi (original id: 1089)
#   239: alfa-sprouts (original id: 1126)
#   240: brussel-sprouts (original id: 1091)
#   241: bacon-cooking (original id: 1916)
#   242: gruyere (original id: 1307)
#   243: bulgur (original id: 1454)
#   244: grapes (original id: 1198)
#   245: pork-escalope (original id: 1760)
#   246: chocolate-egg-small (original id: 2194)
#   247: cappuccino (original id: 2501)
#   248: zucchini-stewed-without-addition-of-fat-without-addition-of-salt (original id: 232)
#   249: crisp-bread-wasa (original id: 1612)
#   250: bread-black (original id: 1557)
#   251: perch-fillets-lake (original id: 2968)
#   252: rosti (original id: 1014)
#   253: mango (original id: 1181)
#   254: sandwich-ham-cheese-and-butter (original id: 2941)
#   255: muesli (original id: 1670)
#   256: spinach-steamed-without-addition-of-salt (original id: 281)
#   257: fish (original id: 1956)
#   258: risotto-without-cheese-cooked (original id: 2970)
#   259: milk-chocolate-with-hazelnuts (original id: 5618)
#   260: cake-oblong (original id: 2259)
#   261: crisps (original id: 2905)
#   262: pork (original id: 1748)
#   263: pomegranate (original id: 1152)
#   264: sweet-corn-canned (original id: 483)
#   265: flakes-oat (original id: 1422)
#   266: greek-salad (original id: 2954)
#   267: cantonese-fried-rice (original id: 5812)
#   268: sesame-seeds (original id: 1223)
#   269: bouillon (original id: 2855)
#   270: baked-potato (original id: 10626)
#   271: fennel (original id: 1119)
#   272: meat (original id: 1707)
#   273: bread-olive (original id: 1546)
#   274: croutons (original id: 2900)
#   275: philadelphia (original id: 1325)
#   276: mushroom-average-stewed-without-addition-of-fat-without-addition-of-salt (original id: 158)
#   277: bell-pepper-red-stewed-without-addition-of-fat-without-addition-of-salt (original id: 656)
#   278: white-chocolate (original id: 2133)
#   279: mixed-nuts (original id: 1220)
#   280: breadcrumbs-unspiced (original id: 1614)
#   281: fondue (original id: 1295)
#   282: sauce-mushroom (original id: 2729)
#   283: tea-spice (original id: 2548)
#   284: strawberries (original id: 1163)
#   285: tea-rooibos (original id: 2563)
#   286: pie-plum-baked-with-cake-dough (original id: 3101)
#   287: potatoes-au-gratin-dauphinois-prepared (original id: 3115)
#   288: capers (original id: 1062)
#   289: vegetables (original id: 1021)
#   290: bread-wholemeal-toast (original id: 1561)
#   291: red-radish (original id: 1074)
#   292: fruit-tart (original id: 2278)
#   293: beans-kidney (original id: 1138)
#   294: sauerkraut (original id: 1093)
#   295: mustard (original id: 2810)
#   296: country-fries (original id: 1007)
#   297: ketchup (original id: 2734)
#   298: pasta-linguini-parpadelle-tagliatelle (original id: 1490)
#   299: chicken-cut-into-stripes-only-meat (original id: 1793)
#   300: cookies (original id: 2376)
#   301: sun-dried-tomatoe (original id: 3293)
#   302: bread-ticino (original id: 1559)
#   303: semi-hard-cheese (original id: 1308)
#   304: margarine (original id: 2062)
#   305: porridge-prepared-with-partially-skimmed-milk (original id: 3615)
#   306: soya-drink-soy-milk (original id: 1256)
#   307: juice-multifruit (original id: 2452)
#   308: popcorn-salted (original id: 2906)
#   309: chocolate-filled (original id: 2135)
#   310: milk-chocolate (original id: 2132)
#   311: bread-fruit (original id: 1533)
#   312: mix-of-dried-fruits-and-nuts (original id: 9594)
#   313: corn (original id: 1108)
#   314: tete-de-moine (original id: 1346)
#   315: dates (original id: 1162)
#   316: pistachio (original id: 1221)
#   317: celery (original id: 1130)
#   318: white-radish (original id: 1076)
#   319: oat-milk (original id: 3046)
#   320: cream-cheese (original id: 1328)
#   321: bread-rye (original id: 1551)
#   322: witloof-chicory (original id: 1033)
#   323: apple-crumble (original id: 2994)
#   324: goat-cheese-soft (original id: 6404)
#   325: grapefruit-pomelo (original id: 1167)
#   326: risotto-with-mushrooms-cooked (original id: 752)
#   327: blue-mould-cheese (original id: 1280)
#   328: biscuit-with-butter (original id: 2408)
#   329: guacamole (original id: 2749)
#   330: pecan-nut (original id: 1219)
#   331: tofu (original id: 1948)
#   332: cordon-bleu-from-pork-schnitzel-fried (original id: 2932)
#   333: paprika-chips (original id: 5689)
#   334: quinoa (original id: 1467)
#   335: kefir-drink (original id: 1249)
#   336: m-m-s (original id: 2184)
#   337: salad-rocket (original id: 1038)
#   338: bread-spelt (original id: 1528)
#   339: pizza-with-ham-with-mushrooms-baked (original id: 629)
#   340: fruit-coulis (original id: 3308)
#   341: plums (original id: 1191)
#   342: beef-minced-only-meat (original id: 1730)
#   343: pizza-with-ham-baked (original id: 630)
#   344: pineapple (original id: 1150)
#   345: soup-tomato (original id: 2852)
#   346: cheddar (original id: 1290)
#   347: tea-fruit (original id: 2546)
#   348: rice-jasmin (original id: 1471)
#   349: seeds (original id: 1205)
#   350: focaccia (original id: 1587)
#   351: milk (original id: 1237)
#   352: coleslaw-chopped-without-sauce (original id: 1020)
#   353: pastry-flaky (original id: 1696)
#   354: curd (original id: 1266)
#   355: savoury-puff-pastry-stick (original id: 2896)
#   356: sweet-potato (original id: 1004)
#   357: chicken-leg (original id: 1794)
#   358: croissant (original id: 1588)
#   359: sour-cream (original id: 1383)
#   360: ham-turkey (original id: 1895)
#   361: processed-cheese (original id: 1337)
#   362: fruit-compotes (original id: 3474)
#   363: cheesecake (original id: 2962)
#   364: pasta-tortelloni-stuffing (original id: 1509)
#   365: sauce-cocktail (original id: 2718)
#   366: croissant-with-chocolate-filling (original id: 2362)
#   367: pumpkin-seeds (original id: 1206)
#   368: artichoke (original id: 1054)
#   369: champagne (original id: 2605)
#   370: grissini (original id: 1616)
#   371: sweets-candies (original id: 2203)
#   372: brie (original id: 1282)
#   373: wienerli-swiss-sausage (original id: 843)
#   374: syrup-diluted-ready-to-drink (original id: 2495)
#   375: apple-pie (original id: 2237)
#   376: white-bread-with-butter-eggs-and-milk (original id: 1584)
#   377: savoury-puff-pastry (original id: 2895)
#   378: anchovies (original id: 1975)
#   379: tuna-in-oil-drained (original id: 922)
#   380: lemon-pie (original id: 3055)
#   381: meat-terrine-pate (original id: 1919)
#   382: coriander (original id: 2767)
#   383: falafel-balls (original id: 2873)
#   384: berries (original id: 1156)
#   385: latte-macchiato-with-caffeine (original id: 2518)
#   386: faux-mage-cashew-vegan-chers (original id: 5247)
#   387: beans-white (original id: 1141)
#   388: sugar-melon (original id: 1184)
#   389: mixed-seeds (original id: 1209)
#   390: hamburger (original id: 1849)
#   391: hamburger-bun (original id: 1572)
#   392: oil-vinegar-salad-dressing (original id: 2747)
#   393: soya-yaourt-yahourt-yogourt-ou-yoghourt (original id: 1257)
#   394: chocolate-milk-chocolate-drink (original id: 3258)
#   395: celeriac (original id: 1082)
#   396: chocolate-mousse (original id: 2961)
#   397: cenovis-yeast-spread (original id: 2791)
#   398: thickened-cream-35 (original id: 1384)
#   399: meringue (original id: 2400)
#   400: lamb-chop (original id: 1770)
#   401: shrimp-prawn-large (original id: 1986)
#   402: beef (original id: 1724)
#   403: lemon (original id: 1200)
#   404: croque-monsieur (original id: 2913)
#   405: chives (original id: 2778)
#   406: chocolate-cookies (original id: 2413)
#   407: birchermuesli-prepared-no-sugar-added (original id: 3220)
#   408: fish-crunchies-battered (original id: 2002)
#   409: muffin (original id: 2312)
#   410: savoy-cabbage-steamed-without-addition-of-salt (original id: 198)
#   411: pine-nuts (original id: 1207)
#   412: chorizo (original id: 1838)
#   413: chia-grains (original id: 4338)
#   414: frying-sausage (original id: 1831)
#   415: french-pizza-from-alsace-baked (original id: 3417)
#   416: chocolate (original id: 2134)
#   417: cooked-sausage (original id: 1883)
#   418: grits-polenta-maize-flour (original id: 1463)
#   419: gummi-bears-fruit-jellies-jelly-babies-with-fruit-essence (original id: 2211)
#   420: wine-rose (original id: 2616)
#   421: coca-cola (original id: 2467)
#   422: raspberries (original id: 1170)
#   423: roll-with-pieces-of-chocolate (original id: 1580)
#   424: goat-average-raw (original id: 3082)
#   425: lemon-cake (original id: 2262)
#   426: coconut-milk (original id: 1253)
#   427: rice-wild (original id: 1479)
#   428: gluten-free-bread (original id: 3306)
#   429: pearl-onions (original id: 1115)
#   430: buckwheat-pancake (original id: 7504)
#   431: bread-5-grain (original id: 1523)
#   432: light-beer (original id: 2636)
#   433: sugar-glazing (original id: 2113)
#   434: tzatziki (original id: 2752)
#   435: butter-herb (original id: 2056)
#   436: ham-croissant (original id: 2920)
#   437: corn-crisps (original id: 2898)
#   438: lentils-green-du-puy-du-berry (original id: 3230)
#   439: cocktail (original id: 2588)
#   440: rice-whole-grain (original id: 1478)
#   441: veal-sausage (original id: 1856)
#   442: cervelat (original id: 1835)
#   443: sorbet (original id: 1411)
#   444: aperitif-with-alcohol-aperol-spritz (original id: 2585)
#   445: dips (original id: 2740)
#   446: corn-flakes (original id: 1626)
#   447: peas (original id: 1107)
#   448: tiramisu (original id: 1371)
#   449: apricots (original id: 1153)
#   450: cake-marble (original id: 2300)
#   451: lamb (original id: 1765)
#   452: lasagne-meat-prepared (original id: 2934)
#   453: coca-cola-zero (original id: 2468)
#   454: cake-salted (original id: 3337)
#   455: dough-puff-pastry-shortcrust-bread-pizza-dough (original id: 1695)
#   456: rice-waffels (original id: 1615)
#   457: sekt (original id: 2610)
#   458: brioche (original id: 1568)
#   459: vegetable-au-gratin-baked (original id: 3532)
#   460: mango-dried (original id: 3228)
#   461: processed-meat-charcuterie (original id: 1857)
#   462: mousse (original id: 1366)
#   463: sauce-sweet-sour (original id: 2731)
#   464: basil (original id: 2760)
#   465: butter-spread-puree-almond (original id: 3249)
#   466: pie-apricot-baked-with-cake-dough (original id: 2990)
#   467: rusk-wholemeal (original id: 1620)
#   468: beef-roast (original id: 1725)
#   469: vanille-cream-cooked-custard-creme-dessert (original id: 236)
#   470: pasta-in-conch-form (original id: 1492)
#   471: nuts (original id: 1211)
#   472: sauce-carbonara (original id: 2716)
#   473: fig-dried (original id: 3392)
#   474: pasta-in-butterfly-form-farfalle (original id: 1488)
#   475: minced-meat (original id: 1711)
#   476: carrot-steamed-without-addition-of-salt (original id: 143)
#   477: ebly (original id: 1456)
#   478: damson-plum (original id: 1201)
#   479: shoots (original id: 1125)
#   480: bouquet-garni (original id: 2768)
#   481: coconut (original id: 1216)
#   482: banana-cake (original id: 5748)
#   483: waffle (original id: 2355)
#   484: apricot-dried (original id: 2960)
#   485: sauce-curry (original id: 2719)
#   486: watermelon-fresh (original id: 578)
#   487: sauce-sweet-salted-asian (original id: 3416)
#   488: pork-roast (original id: 1749)
#   489: blackberry (original id: 1158)
#   490: smoked-cooked-sausage-of-pork-and-beef-meat-sausag (original id: 1908)
#   491: bean-seeds (original id: 1134)
#   492: italian-salad-dressing (original id: 2744)
#   493: white-asparagus (original id: 1124)
#   494: pie-rhubarb-baked-with-cake-dough (original id: 3085)
#   495: tomato-stewed-without-addition-of-fat-without-addition-of-salt (original id: 929)
#   496: cherries (original id: 1175)
#   497: nectarine (original id: 1186)
#
# Training images: 39962
# Validation images: 1000
# Training annotations: 76491
# Validation annotations: 1830

# %% [markdown]
# ## Process Annotations
#
# Convert the COCO format annotations to YOLO format:
# - YOLO expects one text file per image in the "labels" directory
# - Each line in the text file represents one object: `class_id x_center y_center width height x1 y1 x2 y2 ... xn yn`
# - The first 5 values are the class ID and normalized bounding box coordinates (center_x, center_y, width, height)
# - The remaining values are normalized polygon points of the segmentation mask (x1, y1, x2, y2, ...)

# %%
def process_dataset(annotations, src_dir, dest_images_dir, dest_labels_dir):
    # Create image_id to filename mapping
    image_dict = {img['id']: img for img in annotations['images']}
    
    # Group annotations by image_id
    image_annotations = {}
    for ann in annotations['annotations']:
        image_id = ann['image_id']
        if image_id not in image_annotations:
            image_annotations[image_id] = []
        image_annotations[image_id].append(ann)
    
    # Process each image
    for image_id, anns in tqdm(image_annotations.items(), desc="Processing images"):
        image_info = image_dict[image_id]
        filename = image_info['file_name']
        
        # Get image dimensions
        img_width = image_info['width']
        img_height = image_info['height']
        
        # Copy image to destination
        src_path = os.path.join(src_dir, filename)
        dest_path = os.path.join(dest_images_dir, filename)
        shutil.copy(src_path, dest_path)
        
        # Create YOLO annotation file
        label_lines = []
        
        for ann in anns:
            category_id = ann['category_id']
            yolo_class_id = class_ids[category_id]
            
            # Convert bbox to YOLO format (normalized x_center, y_center, width, height)
            x, y, w, h = ann['bbox']
            x_center = (x + w/2) / img_width
            y_center = (y + h/2) / img_height
            width = w / img_width
            height = h / img_height
            
            # Convert segmentation polygon to YOLO format (normalized coordinates)
            if isinstance(ann['segmentation'], list) and len(ann['segmentation']) > 0:
                polygon = ann['segmentation'][0]  # Take the first polygon if there are multiple
                points = []
                for i in range(0, len(polygon), 2):
                    x_coord = polygon[i] / img_width
                    y_coord = polygon[i+1] / img_height
                    points.extend([x_coord, y_coord])
                
                # Create YOLO format line
                line = f"{yolo_class_id} {x_center} {y_center} {width} {height}"
                for p in points:
                    line += f" {p}"
                label_lines.append(line)
        
        # Write label file
        if label_lines:
            label_filename = os.path.splitext(filename)[0] + '.txt'
            with open(os.path.join(dest_labels_dir, label_filename), 'w') as f:
                f.write('\n'.join(label_lines))

# Process training and validation datasets
print("Processing training dataset...")
process_dataset(train_annotations, os.path.join(TRAIN_DIR, "images"), 
                os.path.join(YOLO_DATASET_DIR, "train", "images"), 
                os.path.join(YOLO_DATASET_DIR, "train", "labels"))

print("Processing validation dataset...")
process_dataset(val_annotations, os.path.join(VAL_DIR, "images"), 
                os.path.join(YOLO_DATASET_DIR, "val", "images"), 
                os.path.join(YOLO_DATASET_DIR, "val", "labels"))
# Out:
# Processing training dataset...
# Processing images:   0%|          | 0/39962 [00:00<?, ?it/s]
# Processing validation dataset...
# Processing images:   0%|          | 0/1000 [00:00<?, ?it/s]

# %% [markdown]
# ## Create Dataset Configuration

# %%
# Create dataset.yaml for YOLO training
yaml_content = f"""# YOLO Food Recognition Dataset
path: {YOLO_DATASET_DIR}
train: train/images
val: val/images

# Classes
names:
"""

for cat_id, name in sorted([(class_ids[k], v) for k, v in categories.items()]):
    yaml_content += f"  {cat_id}: '{name}'\n"

# Write YAML file
yaml_path = os.path.join(YOLO_DATASET_DIR, "dataset.yaml")
with open(yaml_path, 'w') as f:
    f.write(yaml_content)

print(f"Dataset configuration saved to {yaml_path}")
print("Sample of the YAML file:")
print("\n".join(yaml_content.split("\n")[:10]) + "\n...")
# Out:
# Dataset configuration saved to /home/kuba/Coding/Uczelnia/fridge_project/datasets/yolo_food_dataset/dataset.yaml
# Sample of the YAML file:
# # YOLO Food Recognition Dataset
# path: /home/kuba/Coding/Uczelnia/fridge_project/datasets/yolo_food_dataset
# train: train/images
# val: val/images
#
# # Classes
# names:
#   0: 'bread-wholemeal'
#   1: 'jam'
#   2: 'water'
# ...

# %% [markdown]
# ## Verify Dataset

# %%
# Count files in dataset directories
train_images = len(list(Path(os.path.join(YOLO_DATASET_DIR, "train", "images")).glob("*")))
train_labels = len(list(Path(os.path.join(YOLO_DATASET_DIR, "train", "labels")).glob("*.txt")))
val_images = len(list(Path(os.path.join(YOLO_DATASET_DIR, "val", "images")).glob("*")))
val_labels = len(list(Path(os.path.join(YOLO_DATASET_DIR, "val", "labels")).glob("*.txt")))

print(f"Train images: {train_images}")
print(f"Train labels: {train_labels}")
print(f"Validation images: {val_images}")
print(f"Validation labels: {val_labels}")

# Sample a few labels to verify
def sample_label(labels_dir, n=3):
    label_files = list(Path(labels_dir).glob("*.txt"))
    if not label_files:
        return "No label files found"
    
    samples = []
    for i in range(min(n, len(label_files))):
        with open(label_files[i], 'r') as f:
            content = f.read().strip()
            samples.append(f"File: {label_files[i].name}\n{content[:300]}{'...' if len(content) > 300 else ''}")
    return "\n\n".join(samples)

print("\nSample training labels:")
print(sample_label(os.path.join(YOLO_DATASET_DIR, "train", "labels")))
# Out:
# Train images: 39962
# Train labels: 39962
# Validation images: 1000
# Validation labels: 1000
#
# Sample training labels:
# File: 131094.txt
# 5 0.25625 0.178125 0.34791666666666665 0.19166666666666668 0.23958333333333334 0.43020833333333336 0.20416666666666666 0.42604166666666665 0.15520833333333334 0.37916666666666665 0.13541666666666666 0.3489583333333333 0.09895833333333333 0.325 0.08229166666666667 0.28541666666666665 0.08229166666666...
#
# File: 131097.txt
# 11 0.5118606138107417 0.44363461538461535 0.7962212276214834 0.6591858974358974 0.40875 0.8847339743589743 0.36625 0.9123044871794871 0.23125 0.8646826923076922 0.15875 0.8471378205128204 0.11375 0.7919967948717948 0.14125 0.7168044871794871 0.25625 0.7318429487179486 0.33375 0.7468814102564103 0.34...
#
# File: 131098.txt
# 12 0.47686061381074163 0.478724358974359 0.6562212276214834 0.6591858974358975 0.58625 0.7894903846153845 0.48375 0.8070352564102563 0.37875000000000003 0.804528846153846 0.25125 0.7293365384615383 0.18625 0.6466249999999999 0.14875 0.5463685897435897 0.14875 0.4761891025641026 0.15375 0.45613782051...
# File: 131094.txt
# 5 0.25625 0.178125 0.34791666666666665 0.19166666666666668 0.23958333333333334 0.43020833333333336 0.20416666666666666 0.42604166666666665 0.15520833333333334 0.37916666666666665 0.13541666666666666 0.3489583333333333 0.09895833333333333 0.325 0.08229166666666667 0.28541666666666665 0.08229166666666...
#
# File: 131097.txt
# 11 0.5118606138107417 0.44363461538461535 0.7962212276214834 0.6591858974358974 0.40875 0.8847339743589743 0.36625 0.9123044871794871 0.23125 0.8646826923076922 0.15875 0.8471378205128204 0.11375 0.7919967948717948 0.14125 0.7168044871794871 0.25625 0.7318429487179486 0.33375 0.7468814102564103 0.34...
#
# File: 131098.txt
# 12 0.47686061381074163 0.478724358974359 0.6562212276214834 0.6591858974358975 0.58625 0.7894903846153845 0.48375 0.8070352564102563 0.37875000000000003 0.804528846153846 0.25125 0.7293365384615383 0.18625 0.6466249999999999 0.14875 0.5463685897435897 0.14875 0.4761891025641026 0.15375 0.45613782051...

# %% [markdown]
# ## Visualize Sample Annotations
#
# Let's visualize some images with their annotations to verify the conversion was successful.

# %%
def draw_yolo_annotations(image_path, label_path):
    # Load image
    img = Image.open(image_path)
    img_width, img_height = img.size
    
    # Create figure
    fig, ax = plt.subplots(1, figsize=(10, 10))
    ax.imshow(img)
    
    # Load labels
    if not os.path.exists(label_path):
        ax.set_title(f"Image: {os.path.basename(image_path)}\nNo annotations found")
        return fig
    
    with open(label_path, 'r') as f:
        lines = f.readlines()
    
    # Draw each annotation
    for line in lines:
        parts = line.strip().split()
        class_id = int(parts[0])
        class_name = next((v for k, v in categories.items() if class_ids[k] == class_id), f"Class {class_id}")
        
        # Bounding box (normalized xywh -> pixel xyxy)
        x_center, y_center, width, height = map(float, parts[1:5])
        x_min = (x_center - width/2) * img_width
        y_min = (y_center - height/2) * img_height
        box_width = width * img_width
        box_height = height * img_height
        
        # Draw rectangle
        rect = plt.Rectangle((x_min, y_min), box_width, box_height,
                            fill=False, edgecolor='red', linewidth=2)
        ax.add_patch(rect)
        ax.text(x_min, y_min, class_name, color='white',
                bbox=dict(facecolor='red', alpha=0.5))
        
        # Draw segmentation polygon if available
        if len(parts) > 5:
            poly_points = parts[5:]
            polygon = []
            for i in range(0, len(poly_points), 2):
                x = float(poly_points[i]) * img_width
                y = float(poly_points[i+1]) * img_height
                polygon.append((x, y))
            
            poly_xs, poly_ys = zip(*polygon)
            ax.plot(poly_xs, poly_ys, '-', color='lime', linewidth=2)
    
    ax.set_title(f"Image: {os.path.basename(image_path)}")
    ax.axis('off')
    return fig

# Visualize a few random examples
def visualize_random_samples(split="train", n=3):
    images_dir = os.path.join(YOLO_DATASET_DIR, split, "images")
    labels_dir = os.path.join(YOLO_DATASET_DIR, split, "labels")
    
    image_files = list(Path(images_dir).glob("*"))
    if not image_files:
        print(f"No images found in {images_dir}")
        return
    
    # Sample n random images
    import random
    sample_images = random.sample(image_files, min(n, len(image_files)))
    
    for img_path in sample_images:
        base_name = os.path.splitext(img_path.name)[0]
        label_path = os.path.join(labels_dir, f"{base_name}.txt")
        fig = draw_yolo_annotations(img_path, label_path)
        plt.tight_layout()
        plt.show()

print("Visualizing training samples:")
visualize_random_samples("train", 3)

print("Visualizing validation samples:")
visualize_random_samples("val", 3)
# Out:
# Visualizing training samples:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 76
#      73         plt.show()
#      75 print("Visualizing training samples:")
# ---> 76 visualize_random_samples("train", 3)
#      78 print("Visualizing validation samples:")
#      79 visualize_random_samples("val", 3)
#
# Cell In[1], line 56, in visualize_random_samples(split, n)
#      55 def visualize_random_samples(split="train", n=3):
# ---> 56     images_dir = os.path.join(YOLO_DATASET_DIR, split, "images")
#      57     labels_dir = os.path.join(YOLO_DATASET_DIR, split, "labels")
#      59     image_files = list(Path(images_dir).glob("*"))
#
# NameError: name 'os' is not defined

# %% [markdown]
# ## Conclusion
#
# This notebook has:
# 1. Converted the food recognition dataset from COCO format to YOLO format
# 2. Created the proper directory structure for training
# 3. Generated a dataset.yaml file with class information
# 4. Verified the conversion with visualizations
#
# Your dataset is now ready for training with YOLOv11n-seg. You can use the training code provided above to start training your model.
