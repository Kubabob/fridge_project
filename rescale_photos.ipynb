# %%
# Import libraries
import matplotlib.pyplot as plt
import os
import random

# %%
# Display a sample image from each dataset
def show_sample_images():
    # Show a sample from food items
    food_path = os.path.join("datasets", "food")
    food_folder_name = random.choice([dir_name for dir_name in os.listdir(food_path)])
    food_folder_path = os.path.join(food_path, food_folder_name)
    food_folder = os.listdir(food_folder_path)
    food_items = [f for f in food_folder]
    
    if food_items:
        food_class = food_folder_name
        food_images = food_items
        if food_images:
            img_path = os.path.join(food_folder_path, food_images[0])
            img = Image.open(img_path)
            plt.figure(figsize=(6, 6))
            plt.title(f"Sample from Food Items: {food_class}")
            plt.imshow(np.array(img))
            plt.axis('off')
            plt.show()
    
    # Show a sample from fruits
    
    fruit_path = os.path.join("datasets", "fruits", "Training")
    fruit_folder_name = random.choice([dir_name for dir_name in os.listdir(fruit_path)])
    fruit_folder_path = os.path.join(fruit_path, fruit_folder_name)
    fruit_folder = os.listdir(fruit_folder_path)
    fruit_items = [f for f in fruit_folder]
    
    if fruit_items:
        fruit_class = fruit_folder_name
        fruit_images = fruit_items
        if fruit_images:
            img_path = os.path.join(fruit_folder_path, fruit_images[0])
            img = Image.open(img_path)
            plt.figure(figsize=(6, 6))
            plt.title(f"Sample from Fruits: {fruit_class}")
            plt.imshow(np.array(img))
            plt.axis('off')
            plt.show()

# Call the function to display sample images

# %%
show_sample_images()
